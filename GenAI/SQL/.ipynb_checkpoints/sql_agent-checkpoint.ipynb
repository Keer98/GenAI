# %%
! pip install pymysql
! pip install chromadb
# !pip install --upgrade --quiet  langchain langchain-community langchain-experimental
# Out:
# Requirement already satisfied: pymysql in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (1.1.1)
# Requirement already satisfied: chromadb in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (0.5.20)
# Requirement already satisfied: build>=1.0.3 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (2.9.2)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.115.5)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.32.1)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (3.7.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.28.2)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (1.68.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.13.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (8.5.0)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (24.1)
# Requirement already satisfied: pyproject_hooks in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from fastapi>=0.95.2->chromadb) (0.41.3)
# Requirement already satisfied: anyio in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (4.6.2.post1)
# Requirement already satisfied: certifi in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.6)
# Requirement already satisfied: idna in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: sniffio in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.8.0)
# Requirement already satisfied: requests in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Requirement already satisfied: requests-oauthlib in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.28.3)
# Requirement already satisfied: sympy in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.49b2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-instrumentation==0.49b2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: opentelemetry-util-http==0.49b2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.49b2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=1.9->chromadb) (2.23.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->chromadb) (2.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.26.2)
# Requirement already satisfied: click>=8.0.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2024.9.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\keert\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)

# %% [markdown]
# <h1>Initialize LLM </h1>

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    api_key="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",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

# %% [markdown]
# <h1>Database Connection</h1>

# %%
from langchain.utilities import SQLDatabase

db_host = "localhost"
db_user = "root"
db_password = "keerthi%4098"
db_name = "kap"
db_port=3305

db = SQLDatabase.from_uri(f"mysql+pymysql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}",sample_rows_in_table_info=0)

print(db.table_info)
# Out:
# CREATE TABLE _archive_calendaroffdates (
# 	`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar that requires specific off dates from scheduled tasks',
# 	`calendarOffDateRepeatTypeId` TINYINT UNSIGNED NOT NULL DEFAULT '1',
# 	`offDate` DATE NOT NULL COMMENT 'specific off date requested from scheduled tasks',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`calendarId`, `calendarOffDateRepeatTypeId`, `offDate`)
# )COMMENT='Specific off dates requested from having tasks by Calendar' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_calendars (
# 	`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key',
# 	`personId` INTEGER UNSIGNED NOT NULL COMMENT 'PersonAccount that owns the Calendar',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`calendarId`)
# )COMMENT='Container to organize a collection of PersonEvents' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetailcalendars (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that owns the assigned Calendar',
# 	`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar assigned to the EnrollmentDetail',
# 	`startDate` DATE NOT NULL COMMENT 'date the Calendar starts',
# 	`endDate` DATE NOT NULL COMMENT 'date the Calendar ends',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='Ties a single EnrollmentDetail to a single Calendar' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetaildownloads (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment detail that was downloaded',
# 	`userAgentId` INTEGER NOT NULL COMMENT 'User agent Id',
# 	ip INTEGER UNSIGNED NOT NULL COMMENT 'IP address' DEFAULT '0',
# 	`downloadCount` TINYINT UNSIGNED COMMENT 'Count of successful download attempts' DEFAULT '0',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`, `userAgentId`, ip)
# )COMMENT='Stores the count of downloads of an offline offeringDetail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetailnodepoints (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that has points assigned to a Node',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Node with points assigned',
# 	`totalPoints` INTEGER UNSIGNED NOT NULL COMMENT 'total points scored on the Node by the EnrollmentDetail',
# 	`totalPointsPossible` INTEGER UNSIGNED NOT NULL COMMENT 'total points possible for the Node by the EnrollmentDetail',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`)
# )COMMENT='Points scored and possible for Nodes by EnrollmentDetail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetailnodequestionstatistics (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'the enrollmentDetailId for these node stats',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'node source for the questions',
# 	`questionId` INTEGER UNSIGNED NOT NULL COMMENT 'question that is assigned to node',
# 	points INTEGER UNSIGNED NOT NULL COMMENT 'points scored for the question',
# 	`pointsPossible` INTEGER UNSIGNED NOT NULL COMMENT 'point possible for the question',
# 	`secondsElapsed` SMALLINT UNSIGNED NOT NULL COMMENT 'seconds elapsed during most recent attempt',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`, `questionId`)
# )COMMENT='stores stats for questions answered within a node' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetailnodestatistics (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'the enrollmentDetailId for these node stats',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'node source for the questions',
# 	`accruedSeconds` INTEGER UNSIGNED NOT NULL COMMENT 'aggregate time for node and its children',
# 	`questionAccruedSeconds` INTEGER UNSIGNED NOT NULL COMMENT 'aggregate time for node questions and child node questions',
# 	`childrenComplete` SMALLINT UNSIGNED NOT NULL COMMENT 'count of completed content for self plus children',
# 	`answeredCount` INTEGER UNSIGNED NOT NULL COMMENT 'number of questions answered in a node',
# 	`incorrectCount` INTEGER UNSIGNED NOT NULL COMMENT 'number of questions answered incorrectly in a node',
# 	points INTEGER UNSIGNED NOT NULL COMMENT 'points achieved for questions answered in a node',
# 	`pointsPossible` INTEGER UNSIGNED NOT NULL COMMENT 'points possible for questions answered in a node',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`)
# )COMMENT='stores sum of stats for questions answered within a node' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetailnodestatus (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that viewed a Node',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Node viewed',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`)
# )COMMENT='The viewed Nodes by EnrollmentDetail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetailnodetimes (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that accumulated time in a Node',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Node in which the time was accumulated',
# 	`accumulatedAt` DATETIME NOT NULL COMMENT 'The date and hour the time was accumulated for an EnrollmentDetail in a Node',
# 	seconds MEDIUMINT UNSIGNED NOT NULL COMMENT 'Time in seconds accumulated by an EnrollmentDetail in a Node on a given date',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`, `accumulatedAt`)
# )COMMENT='The time spent per day by EnrollmentDetail and Node' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetails (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key',
# 	`enrollmentId` INTEGER UNSIGNED NOT NULL COMMENT 'The Enrollment for these OfferingDetailNodeRoot instances',
# 	`offeringDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'The OfferingDetail in this Enrollment',
# 	`lastNodeViewed` INTEGER UNSIGNED COMMENT 'last viewed Node',
# 	`lastNodeViewedAt` TIMESTAMP NULL COMMENT 'timestamp for the last viewed Node',
# 	score TINYINT UNSIGNED COMMENT 'The score for this completed OfferingDetailNodeRoot instance',
# 	`isLocked` TINYINT(1) NOT NULL COMMENT 'Whether or not this EnrollmentDetail is locked from launching' DEFAULT '0',
# 	`startedAt` TIMESTAMP NULL COMMENT 'The time in which the OfferingDetailNodeRoot instance of this Enrollment began',
# 	`completedAt` TIMESTAMP NULL COMMENT 'The time in which the OfferingDetailNodeRoot instance of this Enrollment was completed',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='The OfferingDetailNodeRoot an Enrollment contains' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollmentdetailtokens (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetailId detail of the token',
# 	token CHAR(32) NOT NULL COMMENT 'token for providing enrollment Identity',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='Stores tokens for autorizing to sync offline tests' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_enrollments (
# 	`enrollmentId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key',
# 	`personId` INTEGER UNSIGNED NOT NULL COMMENT 'The Person that owns the Enrollment',
# 	`offeringId` INTEGER UNSIGNED NOT NULL COMMENT 'The Offering that the Person is enrolled in',
# 	`personAssignmentId` INTEGER UNSIGNED NOT NULL COMMENT 'PersonOffering for the Enrollment',
# 	`startedAt` TIMESTAMP NULL COMMENT 'The time in which this Enrollment was started',
# 	`affirmedAt` TIMESTAMP NULL COMMENT 'The time in which this Enrollment was affirmed',
# 	`completedAt` TIMESTAMP NULL COMMENT 'time the Enrollment was completed and just before the certificates service call',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentId`)
# )COMMENT='The instance of a Person launching an Offering' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_instructorenrollments (
# 	`instructorPersonId` INTEGER UNSIGNED NOT NULL COMMENT 'instructor PersonAccount managing the Enrollments',
# 	`enrollmentId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment managed by instructor PersonAccount',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`instructorPersonId`, `enrollmentId`)
# )COMMENT='Join table between instructor PersonAccounts and Enrollments' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_personevents (
# 	`personEventId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key',
# 	`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar the PersonEvent belongs to',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'task type Node for the PersonEvent',
# 	`startTime` TIMESTAMP NOT NULL COMMENT 'time the PersonEvent starts' DEFAULT CURRENT_TIMESTAMP,
# 	`durationSeconds` MEDIUMINT UNSIGNED NOT NULL COMMENT 'duration in seconds of the PersonEvent' DEFAULT '0',
# 	title VARCHAR(255) NOT NULL COMMENT 'title of the PersonEvent',
# 	`shortTitle` VARCHAR(30) COMMENT 'A shortened title for the PersonEvent',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`personEventId`)
# )COMMENT='Calendar of tasks and custom events by PersonAccount' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_personsecurityanswers (
# 	`personId` INTEGER UNSIGNED NOT NULL COMMENT 'Foreign key to the PersonAccounts table',
# 	`securityQuestionId` TINYINT UNSIGNED NOT NULL COMMENT 'Foreign key to the SecurityQuestions table',
# 	answer CHAR(32) NOT NULL COMMENT 'Hash of the answer to the question in the SecurityQuestions record',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`personId`, `securityQuestionId`)
# )COMMENT='Stores archived security answers.' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_securitychallengeresponses (
# 	`securityChallengeId` INTEGER UNSIGNED NOT NULL COMMENT 'SecurityChallenge being attempted',
# 	`securityQuestionId` TINYINT UNSIGNED NOT NULL COMMENT 'SecurityQuestion for attempt',
# 	attempt TINYINT UNSIGNED NOT NULL DEFAULT '1',
# 	response CHAR(32) COMMENT 'the hashed response to the SecurityQuestion, NULL = abandoned/expired',
# 	`isCorrect` TINYINT(1) NOT NULL COMMENT 'is the response correct?' DEFAULT '0',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`securityChallengeId`, `securityQuestionId`, attempt)
# )COMMENT='A SecurityQuestion for each attempt of a SecurityChallenge' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_securitychallenges (
# 	`securityChallengeId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key',
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that triggered the SecurityChallenge',
# 	`securityChallengeStatusId` TINYINT UNSIGNED COMMENT 'status of the SecurityChallenge',
# 	`sourceUrl` VARCHAR(255) NOT NULL COMMENT 'source URL that triggered the SecurityChallenge for redirect upon success',
# 	`ruleCode` VARCHAR(255) NOT NULL COMMENT 'ruleCode that triggered the SecurityChallenge',
# 	`allowedAttempts` TINYINT UNSIGNED NOT NULL COMMENT 'the allowed number of attempts to pass the SecurityChallenge',
# 	`allowedSeconds` SMALLINT UNSIGNED NOT NULL COMMENT 'the time in seconds allowed to pass each attempt of the SecurityChallenge',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`securityChallengeId`)
# )COMMENT='EnrollmentDetail triggered challenges to SecurityQuestions' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_securityquestions (
# 	`securityQuestionId` TINYINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	question VARCHAR(255) NOT NULL COMMENT 'Question text displayed to the person',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`securityQuestionId`)
# )COMMENT='Stores archived security questions.' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_testansweressaymedia (
# 	`testAnswerEssayId` INTEGER UNSIGNED NOT NULL COMMENT 'The TestAnswerEssay the uploaded media applies to',
# 	`mediaId` INTEGER UNSIGNED NOT NULL COMMENT 'Media uploaded to the TestAnswerEssay',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testAnswerEssayId`, `mediaId`)
# )COMMENT='Join table linking TestAnswerEssays to Media' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_testansweressays (
# 	`testAnswerEssayId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	`testQuestionId` BIGINT UNSIGNED NOT NULL COMMENT 'TestQuestion the answer applies to',
# 	`testAnswerEssayContextId` TINYINT UNSIGNED NOT NULL COMMENT 'context for contents of the answerText field' DEFAULT '1',
# 	`answerText` VARCHAR(2000) COMMENT 'text of answer, comment on uploaded media, or instructor response',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testAnswerEssayId`)
# )COMMENT='Answers and responses to essay Questions in a Test' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_testanswers (
# 	`testQuestionId` BIGINT UNSIGNED NOT NULL COMMENT 'TestQuestion for the recorded answer',
# 	`questionOptionId` INTEGER UNSIGNED NOT NULL COMMENT 'QuestionOption of the answer chosen',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testQuestionId`, `questionOptionId`)
# )COMMENT='Recorded answer(s) to the Questions in an instance of a Test' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_testattributes (
# 	`testId` INTEGER UNSIGNED NOT NULL COMMENT 'testId to which the TestAttribute applies for the key',
# 	`key` VARCHAR(100) NOT NULL COMMENT 'key for the TestAttribute for the testId',
# 	value VARCHAR(255) NOT NULL COMMENT 'value of the TestAttribute for a testId and key',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testId`, `key`)
# )COMMENT='Key/value pair table for storing things about tests' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_testlog (
# 	`testLogId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	`testId` INTEGER UNSIGNED NOT NULL COMMENT 'The Test that was archived',
# 	`personId` INTEGER UNSIGNED NOT NULL COMMENT 'The personId of the person who took the Test',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`dbUser` VARCHAR(255) NOT NULL COMMENT 'Result of USER() when Procs.archiveTest is called',
# 	action ENUM('archive','restore') NOT NULL COMMENT 'The action requested: archive or restore',
# 	PRIMARY KEY (`testLogId`)
# )COMMENT='Log of the Tests that have ever been archived.' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_testquestions (
# 	`testQuestionId` BIGINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key',
# 	`testId` INTEGER UNSIGNED NOT NULL COMMENT 'The Test in which the Questions appear',
# 	`parentQuestionId` INTEGER UNSIGNED COMMENT 'questionId of the QuestionSet if applicable',
# 	`questionId` INTEGER UNSIGNED NOT NULL COMMENT 'The Question which appears in the Test',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'nodeId for the question',
# 	`questionAssignmentId` INTEGER UNSIGNED NOT NULL COMMENT 'QuestionAssignment record that assigned the Question to the Test',
# 	`sortOrder` SMALLINT UNSIGNED NOT NULL COMMENT 'Order in which the Questions appear in the Test',
# 	`sortSeed` INTEGER UNSIGNED NOT NULL COMMENT 'Seed to reproduce the random sorting of the QuestionOptions',
# 	points SMALLINT UNSIGNED COMMENT 'points scored on the TestQuestion',
# 	`pointsPossible` SMALLINT UNSIGNED NOT NULL COMMENT 'Points possible for the Question',
# 	`secondsElapsed` INTEGER UNSIGNED NOT NULL COMMENT 'Time in seconds elapsed while the student was actively in the Question',
# 	`isMarkedForReview` TINYINT(1) NOT NULL DEFAULT '0',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testQuestionId`)
# )COMMENT='The Questions in order that appear in a Test instance' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_tests (
# 	`testId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key',
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail to which the Test applies',
# 	`nodeId` INTEGER UNSIGNED COMMENT 'Node source for the Test',
# 	`nodeClassificationId` TINYINT UNSIGNED NOT NULL COMMENT 'classification of the Node source for the Test',
# 	`testStatusId` TINYINT UNSIGNED NOT NULL COMMENT 'TestStatus of the Test' DEFAULT '1',
# 	name VARCHAR(255) NOT NULL COMMENT 'name of the Test',
# 	`lastViewedTestPosition` SMALLINT UNSIGNED COMMENT 'sortOrder of the TestQuestion the Person last viewed',
# 	`totalQuestions` INTEGER UNSIGNED NOT NULL COMMENT 'Number of Questions in the Test',
# 	`totalPoints` INTEGER UNSIGNED COMMENT 'total points scored on the Test',
# 	`totalPointsPossible` INTEGER UNSIGNED NOT NULL COMMENT 'Number of points possible in the Test',
# 	`totalSecondsElapsed` INTEGER UNSIGNED NOT NULL COMMENT 'Total time in seconds elapsed while the student was actively in the Test',
# 	`isInReview` TINYINT(1) NOT NULL COMMENT 'Is the test in Review Mode?' DEFAULT '0',
# 	`startedAt` TIMESTAMP NULL COMMENT 'The time the Test was started',
# 	`endedAt` TIMESTAMP NULL COMMENT 'The time the Test was ended',
# 	`gradedAt` TIMESTAMP NULL COMMENT 'The time the test was graded',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testId`)
# )COMMENT='Instances of tests referencing EnrollmentContent and source' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_testsettings (
# 	`testId` INTEGER UNSIGNED NOT NULL COMMENT 'Test ID',
# 	settings TEXT NOT NULL COMMENT 'json encoded settings',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testId`)
# )COMMENT='Archived test settings' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _archive_testsoffline (
# 	`offlineTestId` CHAR(32) NOT NULL COMMENT 'offline test id',
# 	`testId` INTEGER UNSIGNED NOT NULL COMMENT 'online test id',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`offlineTestId`)
# )COMMENT='Archives Tests created offline' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _tmp_nodestatstimes (
# 	`nodeId` INTEGER UNSIGNED NOT NULL,
# 	`dimensionId` INTEGER UNSIGNED NOT NULL,
# 	`durationSeconds` INTEGER UNSIGNED,
# 	PRIMARY KEY (`nodeId`, `dimensionId`)
# )ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _tmp_parentstats (
# 	`nodeId` INTEGER UNSIGNED NOT NULL,
# 	`durationSeconds` INTEGER UNSIGNED,
# 	PRIMARY KEY (`nodeId`)
# )ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _tmp_test_values (
# 	`testId` INTEGER UNSIGNED NOT NULL,
# 	`key` VARCHAR(100) NOT NULL,
# 	value VARCHAR(255) NOT NULL,
# 	new_value VARCHAR(255) NOT NULL,
# 	PRIMARY KEY (`testId`, `key`)
# )ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE _tmp_teststatusids (
# 	`testId` INTEGER UNSIGNED NOT NULL,
# 	`testStatusId` INTEGER NOT NULL
# )COMMENT='PACE-11380 - Updating the testStatusId of tests to 8 (graded) for Tests that
#     are stuck in a status of 11 (Student Grade Pending), but have all questions scored' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE `enrollmentdetails-trav` (
# 	`enrollmentId` INTEGER UNSIGNED NOT NULL COMMENT 'The Enrollment for these OfferingDetailNodeRoot instances',
# 	`personId` INTEGER UNSIGNED,
# 	`assignmentId` INTEGER UNSIGNED,
# 	offeringid INTEGER UNSIGNED DEFAULT '156360',
# 	`createdAt` TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`createdBy` TINYINT UNSIGNED DEFAULT '1',
# 	`updatedBy` TINYINT UNSIGNED DEFAULT '1'
# )ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE aclresources (
# 	`resourceId` SMALLINT UNSIGNED NOT NULL COMMENT 'Acl Resource Id' AUTO_INCREMENT,
# 	name VARCHAR(255) COMMENT 'Acl Resource Readable Name',
# 	resource VARCHAR(255) NOT NULL COMMENT 'Acl Resource Id',
# 	privilege VARCHAR(255) COMMENT 'Acl Resource Id',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`resourceId`)
# )COMMENT='List of Resources' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE aclroles (
# 	`aclRoleId` SMALLINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	`role` VARCHAR(50) NOT NULL COMMENT 'unique name given to the AclRole',
# 	description VARCHAR(255) COMMENT 'description of the AclRole',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`aclRoleId`)
# )COMMENT='ACL Roles that request access to resources' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE aclrolesgraph (
# 	`parentAclRoleId` SMALLINT UNSIGNED NOT NULL COMMENT 'AclRole from which AclRules are inherited',
# 	`childAclRoleId` SMALLINT UNSIGNED NOT NULL COMMENT 'AclRole to which AclRules are inherited',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`parentAclRoleId`, `childAclRoleId`)
# )COMMENT='Graph the inheritance model of AclRoles' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE aclrules (
# 	`aclRuleId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	`aclRoleId` SMALLINT UNSIGNED COMMENT 'AclRole allowed or denied access to a resource and/or privilege',
# 	`resourceId` SMALLINT UNSIGNED NOT NULL COMMENT 'Acl Resource Id',
# 	`isAllowed` TINYINT(1) NOT NULL COMMENT 'allowed or denied',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`aclRuleId`)
# )COMMENT='Define how resources can be accessed by AclRoles' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activities (
# 	`activityId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity ID' AUTO_INCREMENT,
# 	`activityGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group ID',
# 	`activityTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Activity Type ID',
# 	`activityLabelId` TINYINT UNSIGNED NOT NULL COMMENT 'Activity Label ID' DEFAULT '1',
# 	`sortOrder` MEDIUMINT UNSIGNED NOT NULL COMMENT 'Sort Order of Activity within Activity Group',
# 	name VARCHAR(255) NOT NULL COMMENT 'Activity Name',
# 	content VARCHAR(500) COMMENT 'Activity Content',
# 	`moduleLinkId` INTEGER UNSIGNED COMMENT 'Module Link ID',
# 	`durationMinutes` SMALLINT UNSIGNED COMMENT 'Activity estimated duration in minutes',
# 	`isMilestone` TINYINT UNSIGNED NOT NULL COMMENT 'Whether the activity is a milestone' DEFAULT '0',
# 	`isPerformMilestone` TINYINT UNSIGNED NOT NULL COMMENT 'Whether the activity is a perform milestone' DEFAULT '0',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityId`)
# )COMMENT='Activities assigned to Activity Groups' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitygroupnoderoots (
# 	`activityGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group Id',
# 	`nodeRootId` INTEGER UNSIGNED NOT NULL COMMENT 'Node Root Id',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityGroupId`, `nodeRootId`)
# )COMMENT='Activity Group  Node Roots' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitygroups (
# 	`activityGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group ID' AUTO_INCREMENT,
# 	name VARCHAR(100) NOT NULL COMMENT 'Activity Group Name',
# 	`isArchived` TINYINT UNSIGNED NOT NULL COMMENT 'Whether the Activity Group is Archived',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityGroupId`)
# )COMMENT='Activity Groups' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitygrouptags (
# 	`activityGroupTagId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group Tag ID' AUTO_INCREMENT,
# 	`activityGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group ID',
# 	tag VARCHAR(100) NOT NULL COMMENT 'Activity Group Tag',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityGroupTagId`)
# )COMMENT='Tags used on activities within the group' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitygrouptaskgroups (
# 	`activityGroupTaskGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group TaskGroup ID' AUTO_INCREMENT,
# 	`activityGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group ID',
# 	`taskGroupName` VARCHAR(255) NOT NULL COMMENT 'Name of the Task Group',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityGroupTaskGroupId`)
# )COMMENT='Task Groups to group activities within the activity group' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitygrouptopics (
# 	`activityGroupTopicId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group Topic ID' AUTO_INCREMENT,
# 	`activityGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group ID',
# 	`activityTopicWeightId` TINYINT UNSIGNED COMMENT 'Activity Group Topic Weight',
# 	topic VARCHAR(255) NOT NULL COMMENT 'Activity Group Topic',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityGroupTopicId`)
# )COMMENT='Topics used on activities within the group' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitylabels (
# 	`activityLabelId` TINYINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	name VARCHAR(255) NOT NULL COMMENT 'Activity Label Name',
# 	description VARCHAR(255) NOT NULL COMMENT 'Activity Label description',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityLabelId`)
# )COMMENT='Labels of Activities' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activityperformancetopics (
# 	`activityGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group Id',
# 	`activityId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Id',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Root/Parent Node Id',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityGroupId`, `activityId`, `nodeId`)
# )COMMENT='Activity Performance Topics' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitytags (
# 	`activityId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity ID',
# 	`activityGroupTagId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group Tag ID',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityId`, `activityGroupTagId`)
# )COMMENT='Activity Tags' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitytaskgroup (
# 	`activityId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity ID',
# 	`activityGroupTaskGroupId` INTEGER UNSIGNED NOT NULL COMMENT 'Task Group ID',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityId`)
# )COMMENT='Tags an activity to a task group' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitytopics (
# 	`activityId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity ID',
# 	`activityGroupTopicId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity Group Topic ID',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityId`, `activityGroupTopicId`)
# )COMMENT='Activity Topics' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitytopicweights (
# 	`activityTopicWeightId` TINYINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	name VARCHAR(255) NOT NULL COMMENT 'name for the ActivityTopicWeight',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityTopicWeightId`)
# )COMMENT='Activity topic weights' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE activitytypes (
# 	`activityTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	name VARCHAR(255) NOT NULL COMMENT 'Activity Type Name',
# 	description VARCHAR(255) NOT NULL COMMENT 'Activity Type description',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`activityTypeId`)
# )COMMENT='Types of Activities' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE adaptiveperformancelabels (
# 	`adaptivePerformanceLabelId` TINYINT UNSIGNED NOT NULL COMMENT 'ID for the Performance Label',
# 	label VARCHAR(50) NOT NULL COMMENT 'Performance Label',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`adaptivePerformanceLabelId`)
# )COMMENT='Performance Labels for Adaptive QBank' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE bookmarknotes (
# 	`enrollmentDetailId` INTEGER NOT NULL COMMENT 'EnrollmentDetail that the bookmarkNotes apply to',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Node',
# 	`noteText` TEXT COMMENT 'The text content of the bookmarkNotes',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'Time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'Time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# ...
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`ucmsContentGroupId` BIGINT UNSIGNED COMMENT 'Ucms Content Group ID',
# 	PRIMARY KEY (`ucmsId`)
# )COMMENT='UCMS media records' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmsassignments (
# 	`ucmsId` BIGINT UNSIGNED NOT NULL COMMENT 'ucms that is assigned to Content',
# 	`contentId` INTEGER UNSIGNED NOT NULL COMMENT 'Content that is assigned to ucmsPresentation',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsId`, `contentId`)
# )COMMENT='Assigns a ucms57Presentation to Content' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmscontentgroups (
# 	`ucmsContentGroupId` BIGINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing primary key' AUTO_INCREMENT,
# 	name VARCHAR(255) NOT NULL COMMENT 'The name of the ucms content groups',
# 	`assetCount` INTEGER UNSIGNED COMMENT 'Asset count of the ucms content group',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsContentGroupId`)
# )COMMENT='Content Groups of Ucms Lite' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmshostaccounts (
# 	`ucmsHostAccountId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto incrementinng Primary Key' AUTO_INCREMENT,
# 	`ucmsHostTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Ucms Host type ID',
# 	`accountId` VARCHAR(50) COMMENT 'Account ID',
# 	`accountName` VARCHAR(50) COMMENT 'Account Name',
# 	`ucmsHostTypeAccountId` TINYINT COMMENT 'UCMS Hosttype Account ID',
# 	`clientId` VARCHAR(100) COMMENT 'Client ID',
# 	`clientSecret` VARCHAR(250) COMMENT 'Client Secret',
# 	username VARCHAR(50) COMMENT 'Account Username',
# 	password VARCHAR(50) COMMENT 'Account Password',
# 	`policyKey` VARCHAR(250) COMMENT 'Policy Key',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsHostAccountId`)
# )COMMENT='Ucms Host Accounts' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmshosts (
# 	`ucmsHostId` INTEGER UNSIGNED NOT NULL COMMENT 'Host ID' AUTO_INCREMENT,
# 	`ucmsId` BIGINT UNSIGNED NOT NULL COMMENT 'UCMS ID',
# 	`ucmsHostTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Host type ID',
# 	`isActive` TINYINT UNSIGNED NOT NULL COMMENT 'Whether host is active',
# 	`isEditable` TINYINT(1) NOT NULL COMMENT '1 => editable true, 0 => false record is not editable' DEFAULT '1',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsHostId`)
# )COMMENT='UCMS media hosts' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmshostseminars (
# 	`ucmsHostId` INTEGER UNSIGNED NOT NULL COMMENT 'Host ID',
# 	`ucmsHostTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Host type ID',
# 	`ucmsHostForeignId` BIGINT COMMENT 'Host foreign ID',
# 	`startDate` TIMESTAMP NOT NULL COMMENT 'Start date',
# 	`durationMinutes` SMALLINT NOT NULL COMMENT 'Duration in minutes',
# 	`ucmsHostAccountId` INTEGER UNSIGNED NOT NULL COMMENT 'Ucms Host Account ID',
# 	`instructorId` INTEGER COMMENT 'PersonID of the instructor for the seminar',
# 	`groupName` VARCHAR(50) COMMENT 'Name of the group',
# 	`ucmsRoomTypeId` INTEGER COMMENT 'UCMS Room Type Id',
# 	`ucmsHostSeminarSubTypeId` TINYINT COMMENT 'UCMS Host Seminar Subtype ID',
# 	`roomVerified` TINYINT COMMENT 'Room is Verified' DEFAULT '0',
# 	`ucmsHostAlternateForeignId` VARCHAR(255) COMMENT 'Alternate UCMS Host Foreign ID',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsHostId`)
# )COMMENT='UCMS Live Seminar Hosts' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmshostseminarsubtypes (
# 	`ucmsHostSeminarSubTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'UCMS Host Seminar Subtype ID' AUTO_INCREMENT,
# 	name VARCHAR(50) NOT NULL COMMENT 'UCMS Seminar Subtype name',
# 	`ucmsHostTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Ucms Host type ID',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsHostSeminarSubTypeId`)
# )COMMENT='UCMS Seminar Subtypes' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmshosttypeaccounts (
# 	`ucmsHostTypeAccountId` TINYINT UNSIGNED NOT NULL COMMENT 'UCMS Host type Account ID' AUTO_INCREMENT,
# 	`ucmsHostTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Ucms Host type ID',
# 	name VARCHAR(50) NOT NULL COMMENT 'Name of the account type',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsHostTypeAccountId`)
# )COMMENT='Stores the types of accounts' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmshosttypes (
# 	`ucmsHostTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Host type ID',
# 	name VARCHAR(50) NOT NULL COMMENT 'Host type name',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsHostTypeId`)
# )COMMENT='UCMS media host types' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmshostvideos (
# 	`ucmsHostId` INTEGER UNSIGNED NOT NULL COMMENT 'Host ID',
# 	`ucmsHostTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Host type ID',
# 	`ucmsHostForeignId` BIGINT COMMENT 'Host foreign ID',
# 	`cuePoints` VARCHAR(255) COMMENT 'Cue points',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsHostId`)
# )COMMENT='UCMS Video hosts' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmspollquestions (
# 	`ucmsPollQuestionId` INTEGER UNSIGNED NOT NULL COMMENT 'the poll question id' AUTO_INCREMENT,
# 	`ucmsPollId` INTEGER UNSIGNED NOT NULL COMMENT 'the poll id',
# 	`securityQuestionId` TINYINT UNSIGNED NOT NULL COMMENT 'security question Id',
# 	`displayAt` TIMESTAMP NOT NULL COMMENT 'the time at which the question should be displayed to the user',
# 	`isAnswered` TINYINT UNSIGNED COMMENT 'Is the question answered or not',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsPollQuestionId`)
# )COMMENT='Polling questions related to the Polls' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmspolls (
# 	`ucmsPollId` INTEGER UNSIGNED NOT NULL COMMENT 'the poll id' AUTO_INCREMENT,
# 	`ucmsId` BIGINT UNSIGNED NOT NULL COMMENT 'UCMS Id',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsPollId`)
# )COMMENT='Polls to track student presence in a seminar' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmspollvisibility (
# 	`ucmsPollQuestionId` INTEGER UNSIGNED NOT NULL COMMENT 'The poll question id',
# 	`isPollVisible` TINYINT UNSIGNED COMMENT 'Is the poll question visible',
# 	`visibleAt` VARCHAR(255) COMMENT 'When was the poll question visible',
# 	`mouseMoved` TINYINT UNSIGNED COMMENT 'Is there any mouse movement',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsPollQuestionId`)
# )COMMENT='Tracking data related to polling question visibility' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmsproducthostmappings (
# 	`ucmsProductHostMappingId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing primary key' AUTO_INCREMENT,
# 	`productGroup` VARCHAR(50) NOT NULL COMMENT 'The name of the product group',
# 	`productLevel` VARCHAR(20) NOT NULL,
# 	`orgCodes` VARCHAR(255),
# 	name VARCHAR(255) NOT NULL COMMENT 'The name of the mapping',
# 	`ucmsHostTypeId` TINYINT NOT NULL COMMENT 'Id of ucms host type',
# 	`ucmsHostAccountId` INTEGER UNSIGNED NOT NULL COMMENT 'Ucms Host Account ID',
# 	`ucmsHostSeminarSubTypeId` TINYINT COMMENT 'UCMS Host Seminar Subtype ID',
# 	`ucmsHostTypeAccountId` TINYINT COMMENT 'UCMS Hosttype Account ID',
# 	PRIMARY KEY (`ucmsProductHostMappingId`)
# )COMMENT='UCMS Product Host Mapping' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmsroomtypes (
# 	`ucmsRoomTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'UCMS Room type ID' AUTO_INCREMENT,
# 	name VARCHAR(50) NOT NULL COMMENT 'UCMS Room type name',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsRoomTypeId`)
# )COMMENT='UCMS Room types' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmsstatistics (
# 	`ucmsId` BIGINT NOT NULL COMMENT 'The UCMS ID that the statistics apply to',
# 	`enrollmentDetailId` INTEGER NOT NULL COMMENT 'EnrollmentDetail that the UCMS statistics apply to',
# 	`currentPosition` SMALLINT UNSIGNED COMMENT 'The current position',
# 	`maxPosition` SMALLINT UNSIGNED COMMENT 'The max position',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'Time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'Time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsId`, `enrollmentDetailId`)
# )COMMENT='Stores current and max positions for a media asset and enrollment detail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE ucmstypes (
# 	`ucmsTypeId` TINYINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	name VARCHAR(255) NOT NULL COMMENT 'The name of the NodeRootType',
# 	description VARCHAR(255) NOT NULL COMMENT 'The description of the NodeRootType',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsTypeId`)
# )COMMENT='Types of Ucms' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE useragents (
# 	`userAgentId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	`userAgent` VARCHAR(255) NOT NULL COMMENT 'user agent string',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	PRIMARY KEY (`userAgentId`)
# )COMMENT='Stores unique user agents' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
# CREATE TABLE videochannels (
# 	`videoChannelId` INTEGER UNSIGNED NOT NULL COMMENT 'Video Channel ID' AUTO_INCREMENT,
# 	name VARCHAR(100) NOT NULL COMMENT 'Video Channel Name',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`videoChannelId`)
# )COMMENT='Video Channels for Categorizing Enrollment Detail Videos' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3

# %% [markdown]
# <h1>Chunck database</h1>

# %%
import chromadb
from chromadb.config import Settings
from sentence_transformers import SentenceTransformer

# Initialize ChromaDB client
chroma_client = chromadb.Client(Settings(
    persist_directory="./db_embeddings"  # Path to save embeddings
))

# Create or get the collection
collection_name = "table_embeddings"
collection = chroma_client.get_or_create_collection(name=collection_name)

# Initialize embedding model
MODEL_NAME = "all-mpnet-base-v2"
model = SentenceTransformer(MODEL_NAME)
# Out:
# WARNING:tensorflow:From C:\Users\keert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# Assume db.table_info is a list of table descriptions, one per table
table_metadata = db.table_info.split("\nCREATE TABLE")  # Split based on the "CREATE TABLE" keyword

# Add back the "CREATE TABLE" prefix to each chunk
table_metadata = [f"CREATE TABLE{chunk}" for chunk in table_metadata if chunk.strip()]

# Chunk into groups of 20 tables
table_chunks = [table_metadata[i:i + 10] for i in range(0, len(table_metadata), 10)]

# Process each chunk for embedding and adding to ChromaDB
for idx, chunk in enumerate(table_chunks):
    chunk_description = " ".join(chunk)  # Combine all table schemas in the chunk into a single string
    embedding = model.encode(chunk_description)  # Generate embedding for the chunk
    
    # Add to the ChromaDB collection
    collection.add(
        ids=[f"chunk_{idx}"],  # Unique ID for each chunk
        documents=[chunk_description],  # Document data (merged schema descriptions)
        metadatas=[{"chunk_id": idx}],  # Metadata for identifying the chunk
        embeddings=[embedding]  # Embedding vector
    )

# %%
# Function to print entire collection
def print_entire_collection(collection):
    # Retrieve all data from the collection with embeddings included
    data = collection.get(include=["embeddings", "documents", "metadatas"])
    
    # Print the retrieved data
    print("Collection Data:")
    print(data)

# Print the entire collection
print_entire_collection(collection)
# Out:
# Collection Data:
# {'ids': ['chunk_0', 'chunk_1', 'chunk_2', 'chunk_3', 'chunk_4', 'chunk_5', 'chunk_6', 'chunk_7', 'chunk_8', 'chunk_9', 'chunk_10', 'chunk_11', 'chunk_12', 'chunk_13', 'chunk_14', 'chunk_15', 'chunk_16', 'chunk_17', 'chunk_18', 'chunk_19', 'chunk_20', 'chunk_21', 'chunk_22', 'chunk_23', 'chunk_24', 'chunk_25'], 'embeddings': array([[-0.00310511,  0.07523103, -0.05050876, ...,  0.03410833,
#          0.00547077, -0.02757739],
#        [ 0.00797086,  0.05271627, -0.03469973, ...,  0.02112977,
#         -0.00623444, -0.00542561],
#        [ 0.02565437,  0.09781154, -0.03381799, ...,  0.05306804,
#         -0.06058244, -0.03049197],
#        ...,
#        [ 0.0186752 ,  0.01685011, -0.04692404, ...,  0.02236028,
#         -0.03578341, -0.04569038],
#        [-0.0110248 ,  0.02598479, -0.02141585, ..., -0.00238255,
#         -0.0336582 , -0.02319941],
#        [-0.01303965,  0.01546412, -0.03801164, ...,  0.05073396,
#         -0.06654085, -0.05758171]]), 'documents': ["CREATE TABLE _archive_calendaroffdates (\n\t`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar that requires specific off dates from scheduled tasks', \n\t`calendarOffDateRepeatTypeId` TINYINT UNSIGNED NOT NULL DEFAULT '1', \n\t`offDate` DATE NOT NULL COMMENT 'specific off date requested from scheduled tasks', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\t`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (`calendarId`, `calendarOffDateRepeatTypeId`, `offDate`)\n)COMMENT='Specific off dates requested from having tasks by Calendar' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3\n\n CREATE TABLE _archive_calendars (\n\t`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key', \n\t`personId` INTEGER UNSIGNED NOT NULL COMMENT 'PersonAccount that owns the Calendar', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\t`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (`calendarId`)\n)COMMENT='Container to organize a collection of PersonEvents' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3\n\n CREATE TABLE _archive_enrollmentdetailcalendars (\n\t`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that owns the assigned Calendar', \n\t`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar assigned to the EnrollmentDetail', \n\t`startDate` DATE NOT NULL COMMENT 'date the Calendar starts', \n\t`endDate` DATE NOT NULL COMMENT 'date the Calendar ends', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\t`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (`enrollmentDetailId`)\n)COMMENT='Ties a single EnrollmentDetail to a single Calendar' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3\n\n CREATE TABLE _archive_enrollmentdetaildownloads (\n\t`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment detail that was downloaded', \n\t`userAgentId` INTEGER NOT NULL COMMENT 'User agent Id', \n\tip INTEGER UNSIGNED NOT NULL COMMENT 'IP address' DEFAULT '0', \n\t`downloadCount` TINYINT UNSIGNED COMMENT 'Count of successful download attempts' DEFAULT '0', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\t`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (`enrollmentDetailId`,  ...

# %%
import re

# Function to extract table names from relevant chunks
def extract_table_names(chunks):
    
    table_pattern = r"CREATE TABLE\s+`?(\w+)`?"  # Regex to match CREATE TABLE statements and capture table name

   
    for line in chunks.split("\n"):  # Split chunk into lines
        match = re.search(table_pattern, line)  # Search for table name in line
        if match:
           
            table_name = match.group(1)  # Extract the table name
            table_names.append(table_name)

    return table_names

# %%
# User's query
query_text = "how many unique start dates in enrollmentdetailcalendars"

# Generate embedding for the query
query_embedding = model.encode(query_text)

# Retrieve top 3 most relevant chunks
results = collection.query(
    query_embeddings=[query_embedding],  # Embedding of the query
    n_results=3,  # Number of top results to retrieve
    include=["documents", "metadatas"]  # Include relevant metadata and documents
)

# Extract the top chunks
relevant_chunks = results["documents"]  # List of top chunk descriptions
relevant_metadata = results["metadatas"]  # Metadata for the chunks (optional for tracking)

# Print retrieved chunks for debugging
print("Relevant Chunks:")

table_names=[]
for i, chunk in enumerate(relevant_chunks):
    for j,c in enumerate(chunk):
        print(f"Chunk {j + 1}:\n{c}\n")
        table_names.extend(extract_table_names(c))
# Out:
# Relevant Chunks:
# Chunk 1:
# CREATE TABLE enrollmentdetailactivitystatus (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment Detail to which the activity was assigned',
# 	`activityId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity that was completed',
# 	`isComplete` TINYINT(1) NOT NULL COMMENT 'Whether the activity is completed' DEFAULT '0',
# 	`markedForReview` TINYINT(1) NOT NULL COMMENT 'Whether the activity is marked for review' DEFAULT '0',
# 	`completedAt` TIMESTAMP NULL COMMENT 'time the activity was completed',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `activityId`)
# )COMMENT='Activities completed in an Enrollment Detail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailcalendars (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that owns the assigned Calendar',
# 	`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar assigned to the EnrollmentDetail',
# 	`startDate` DATE NOT NULL COMMENT 'date the Calendar starts',
# 	`endDate` DATE NOT NULL COMMENT 'date the Calendar ends',
# 	hash CHAR(32) COMMENT 'Hash of calendar setting during activity schedule',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='Ties a single EnrollmentDetail to a single Calendar' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetaildownloads (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment detail that was downloaded',
# 	`userAgentId` INTEGER NOT NULL COMMENT 'User agent Id',
# 	ip INTEGER UNSIGNED NOT NULL COMMENT 'IP address' DEFAULT '0',
# 	`downloadCount` TINYINT UNSIGNED COMMENT 'Count of successful download attempts' DEFAULT '0',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `userAgentId`, ip)
# )COMMENT='Stores the count of downloads of an offline offeringDetail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailhighlights (
# 	`enrollmentDetailId` INTEGER NOT NULL COMMENT 'EnrollmentDetail that the highlights apply to',
# 	`testId` INTEGER UNSIGNED NOT NULL COMMENT 'testId of the highlights, optional field',
# 	`key` VARCHAR(100) NOT NULL COMMENT 'Key name for data',
# 	value VARCHAR(255) NOT NULL COMMENT 'Page param value',
# 	`range` VARCHAR(500) NOT NULL COMMENT 'highlighted text range',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'Time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'Time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `key`, value, `testId`)
# )COMMENT='Stores EnrollmentDetail Highlights' ENGINE=InnoDB DEFAULT CHARSET=latin1
#
#  CREATE TABLE enrollmentdetaillinks (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that owns the 3rd Party Link ID',
# 	`linkId` BIGINT UNSIGNED NOT NULL COMMENT 'The associated 3rd Party Link ID',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='Ties a single EnrollmentDetail to a 3rd Party Link' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailnodeadaptiveratings (
# 	`enrollmentDetailNodeAdaptiveRatingId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-Incrementing Primary Key' AUTO_INCREMENT,
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment Detail ID',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Node ID',
# 	rating INTEGER UNSIGNED NOT NULL COMMENT 'Adaptive Rating',
# 	`adaptivePerformanceLabelId` TINYINT UNSIGNED COMMENT 'The performance label for the rating',
# 	`questionId` INTEGER UNSIGNED COMMENT 'The question answered to achieve the rating',
# 	`parentQuestionId` INTEGER UNSIGNED COMMENT 'The parent question of the answered question',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailNodeAdaptiveRatingId`)
# )COMMENT='History of adaptive ratings for enrollment detail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailnodepoints (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that has points assigned to a Node',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Node with points assigned',
# 	`totalPoints` INTEGER UNSIGNED NOT NULL COMMENT 'total points scored on the Node by the EnrollmentDetail',
# 	`totalPointsPossible` INTEGER UNSIGNED NOT NULL COMMENT 'total points possible for the Node by the EnrollmentDetail',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`)
# )COMMENT='Points scored and possible for Nodes by EnrollmentDetail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailnodequestionbookmarknotes (
# 	`enrollmentDetailId` INTEGER NOT NULL COMMENT 'EnrollmentDetail that the bookmarkNotes apply to',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'node source for the questions',
# 	`questionId` INTEGER UNSIGNED NOT NULL COMMENT 'QuestionId',
# 	`noteText` TEXT COMMENT 'The text content of the Question BookmarkNotes',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'Time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'Time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`, `questionId`)
# )COMMENT='Stores Question BookmarkNotes text message' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailnodequestionstatistics (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'the enrollmentDetailId for these node stats',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'node source for the questions',
# 	`questionId` INTEGER UNSIGNED NOT NULL COMMENT 'question that is assigned to node',
# 	points INTEGER UNSIGNED NOT NULL COMMENT 'points scored for the question',
# 	`pointsPossible` INTEGER UNSIGNED NOT NULL COMMENT 'point possible for the question',
# 	`secondsElapsed` SMALLINT UNSIGNED NOT NULL COMMENT 'seconds elapsed during most recent attempt',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`, `questionId`)
# )COMMENT='stores stats for questions answered within a node' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailnodestatistics (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'the enrollmentDetailId for these node stats',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'node source for the questions',
# 	`accruedSeconds` INTEGER UNSIGNED NOT NULL COMMENT 'aggregate time for node and its children' DEFAULT '0',
# 	`questionAccruedSeconds` INTEGER UNSIGNED NOT NULL COMMENT 'aggregate time for node questions and child node questions' DEFAULT '0',
# 	`childrenComplete` SMALLINT UNSIGNED NOT NULL COMMENT 'count of completed content for self plus children' DEFAULT '0',
# 	`answeredCount` INTEGER UNSIGNED NOT NULL COMMENT 'number of questions answered in a node' DEFAULT '0',
# 	`incorrectCount` INTEGER UNSIGNED NOT NULL COMMENT 'number of questions answered incorrectly in a node' DEFAULT '0',
# 	points INTEGER UNSIGNED NOT NULL COMMENT 'points achieved for questions answered in a node' DEFAULT '0',
# 	`pointsPossible` INTEGER UNSIGNED NOT NULL COMMENT 'points possible for questions answered in a node' DEFAULT '0',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`)
# )COMMENT='stores sum of stats for questions answered within a node' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
#
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# Chunk 2:
# CREATE TABLE _archive_enrollmentdetailtokens (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetailId detail of the token',
# 	token CHAR(32) NOT NULL COMMENT 'token for providing enrollment Identity',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='Stores tokens for autorizing to sync offline tests' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_enrollments (
# 	`enrollmentId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key',
# 	`personId` INTEGER UNSIGNED NOT NULL COMMENT 'The Person that owns the Enrollment',
# 	`offeringId` INTEGER UNSIGNED NOT NULL COMMENT 'The Offering that the Person is enrolled in',
# 	`personAssignmentId` INTEGER UNSIGNED NOT NULL COMMENT 'PersonOffering for the Enrollment',
# 	`startedAt` TIMESTAMP NULL COMMENT 'The time in which this Enrollment was started',
# 	`affirmedAt` TIMESTAMP NULL COMMENT 'The time in which this Enrollment was affirmed',
# 	`completedAt` TIMESTAMP NULL COMMENT 'time the Enrollment was completed and just before the certificates service call',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`enrollmentId`)
# )COMMENT='The instance of a Person launching an Offering' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_instructorenrollments (
# 	`instructorPersonId` INTEGER UNSIGNED NOT NULL COMMENT 'instructor PersonAccount managing the Enrollments',
# 	`enrollmentId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment managed by instructor PersonAccount',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`instructorPersonId`, `enrollmentId`)
# )COMMENT='Join table between instructor PersonAccounts and Enrollments' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_personevents (
# 	`personEventId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key',
# 	`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar the PersonEvent belongs to',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'task type Node for the PersonEvent',
# 	`startTime` TIMESTAMP NOT NULL COMMENT 'time the PersonEvent starts' DEFAULT CURRENT_TIMESTAMP,
# 	`durationSeconds` MEDIUMINT UNSIGNED NOT NULL COMMENT 'duration in seconds of the PersonEvent' DEFAULT '0',
# 	title VARCHAR(255) NOT NULL COMMENT 'title of the PersonEvent',
# 	`shortTitle` VARCHAR(30) COMMENT 'A shortened title for the PersonEvent',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`personEventId`)
# )COMMENT='Calendar of tasks and custom events by PersonAccount' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_personsecurityanswers (
# 	`personId` INTEGER UNSIGNED NOT NULL COMMENT 'Foreign key to the PersonAccounts table',
# 	`securityQuestionId` TINYINT UNSIGNED NOT NULL COMMENT 'Foreign key to the SecurityQuestions table',
# 	answer CHAR(32) NOT NULL COMMENT 'Hash of the answer to the question in the SecurityQuestions record',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`personId`, `securityQuestionId`)
# )COMMENT='Stores archived security answers.' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_securitychallengeresponses (
# 	`securityChallengeId` INTEGER UNSIGNED NOT NULL COMMENT 'SecurityChallenge being attempted',
# 	`securityQuestionId` TINYINT UNSIGNED NOT NULL COMMENT 'SecurityQuestion for attempt',
# 	attempt TINYINT UNSIGNED NOT NULL DEFAULT '1',
# 	response CHAR(32) COMMENT 'the hashed response to the SecurityQuestion, NULL = abandoned/expired',
# 	`isCorrect` TINYINT(1) NOT NULL COMMENT 'is the response correct?' DEFAULT '0',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`securityChallengeId`, `securityQuestionId`, attempt)
# )COMMENT='A SecurityQuestion for each attempt of a SecurityChallenge' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_securitychallenges (
# 	`securityChallengeId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key',
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that triggered the SecurityChallenge',
# 	`securityChallengeStatusId` TINYINT UNSIGNED COMMENT 'status of the SecurityChallenge',
# 	`sourceUrl` VARCHAR(255) NOT NULL COMMENT 'source URL that triggered the SecurityChallenge for redirect upon success',
# 	`ruleCode` VARCHAR(255) NOT NULL COMMENT 'ruleCode that triggered the SecurityChallenge',
# 	`allowedAttempts` TINYINT UNSIGNED NOT NULL COMMENT 'the allowed number of attempts to pass the SecurityChallenge',
# 	`allowedSeconds` SMALLINT UNSIGNED NOT NULL COMMENT 'the time in seconds allowed to pass each attempt of the SecurityChallenge',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`securityChallengeId`)
# )COMMENT='EnrollmentDetail triggered challenges to SecurityQuestions' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_securityquestions (
# 	`securityQuestionId` TINYINT UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	question VARCHAR(255) NOT NULL COMMENT 'Question text displayed to the person',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`securityQuestionId`)
# )COMMENT='Stores archived security questions.' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_testansweressaymedia (
# 	`testAnswerEssayId` INTEGER UNSIGNED NOT NULL COMMENT 'The TestAnswerEssay the uploaded media applies to',
# 	`mediaId` INTEGER UNSIGNED NOT NULL COMMENT 'Media uploaded to the TestAnswerEssay',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testAnswerEssayId`, `mediaId`)
# )COMMENT='Join table linking TestAnswerEssays to Media' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE _archive_testansweressays (
# 	`testAnswerEssayId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	`testQuestionId` BIGINT UNSIGNED NOT NULL COMMENT 'TestQuestion the answer applies to',
# 	`testAnswerEssayContextId` TINYINT UNSIGNED NOT NULL COMMENT 'context for contents of the answerText field' DEFAULT '1',
# 	`answerText` VARCHAR(2000) COMMENT 'text of answer, comment on uploaded media, or instructor response',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP,
# 	PRIMARY KEY (`testAnswerEssayId`)
# )COMMENT='Answers and responses to essay Questions in a Test' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
#
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# Chunk 3:
# CREATE TABLE enrollmentdetailnodestatus (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that viewed a Node',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Node viewed',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`)
# )COMMENT='The viewed Nodes by EnrollmentDetail' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailnodetimes (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that accumulated time in a Node',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'Node in which the time was accumulated',
# 	`accumulatedAt` DATETIME NOT NULL COMMENT 'The date and hour the time was accumulated for an EnrollmentDetail in a Node',
# 	seconds MEDIUMINT UNSIGNED NOT NULL COMMENT 'Time in seconds accumulated by an EnrollmentDetail in a Node on a given date',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`, `accumulatedAt`)
# )COMMENT='The time spent per day by EnrollmentDetail and Node' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetails (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	`enrollmentId` INTEGER UNSIGNED NOT NULL COMMENT 'The Enrollment for these OfferingDetailNodeRoot instances',
# 	`offeringDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'The OfferingDetail in this Enrollment',
# 	`lastNodeViewed` INTEGER UNSIGNED COMMENT 'last viewed Node',
# 	`lastNodeViewedAt` TIMESTAMP NULL COMMENT 'timestamp for the last viewed Node',
# 	`lastViewedAt` TIMESTAMP NULL COMMENT 'The time that this detail was last viewed',
# 	score TINYINT UNSIGNED COMMENT 'The score for this completed OfferingDetailNodeRoot instance',
# 	`isLocked` TINYINT(1) NOT NULL COMMENT 'Whether or not this EnrollmentDetail is locked from launching' DEFAULT '0',
# 	`startedAt` TIMESTAMP NULL COMMENT 'The time in which the OfferingDetailNodeRoot instance of this Enrollment began',
# 	`completedAt` TIMESTAMP NULL COMMENT 'The time in which the OfferingDetailNodeRoot instance of this Enrollment was completed',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='The OfferingDetailNodeRoot an Enrollment contains' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailsettings (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'enrollment detail',
# 	settings TEXT NOT NULL COMMENT 'json encoded settings',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='Enrollment detail settings' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailtokens (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetailId detail of the token',
# 	token CHAR(32) NOT NULL COMMENT 'token for providing enrollment Identity',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='Stores tokens for autorizing to sync offline tests' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailucmsstatistics (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'the enrollmentDetailId',
# 	`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'node Id',
# 	`ucmsId` BIGINT UNSIGNED NOT NULL COMMENT 'UCMS Id',
# 	`accruedSeconds` INTEGER UNSIGNED COMMENT 'accrued time in seconds in the live seminar',
# 	`lastViewedAt` TIMESTAMP NULL COMMENT 'the time that this live seminar was last viewed',
# 	`ucmsPollId` INTEGER UNSIGNED COMMENT 'poll id for this live seminar',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`, `nodeId`, `ucmsId`)
# )COMMENT='stores stats for live seminars within a node' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailvideochannels (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment Detail ID',
# 	`videoChannelId` INTEGER UNSIGNED NOT NULL COMMENT 'Video Channel ID',
# 	`ucmsId` BIGINT UNSIGNED NOT NULL COMMENT 'UCMS ID to add to channel',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`ucmsId`, `enrollmentDetailId`, `videoChannelId`)
# )COMMENT='Enrollment Detail Videos added to Video Channel' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentdetailvouchers (
# 	`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetailId detail of the Voucher',
# 	voucher VARCHAR(64) NOT NULL COMMENT 'voucher code for downloading a product like Gmetrix',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentDetailId`)
# )COMMENT='Stores voucher codes for downloading a product like Gmetrix' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollmentportalcodes (
# 	`enrollmentId` INTEGER NOT NULL COMMENT 'Enrollment ID',
# 	`portalCode` CHAR(50) NOT NULL COMMENT 'PortalCode',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'Time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'Time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentId`)
# )COMMENT='Stores PortalCode information to Enrollment records' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#  CREATE TABLE enrollments (
# 	`enrollmentId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT,
# 	`personId` INTEGER UNSIGNED NOT NULL COMMENT 'The Person that owns the Enrollment',
# 	`offeringId` INTEGER UNSIGNED NOT NULL COMMENT 'The Offering that the Person is enrolled in',
# 	`personAssignmentId` INTEGER UNSIGNED NOT NULL COMMENT 'PersonOffering for the Enrollment',
# 	`startedAt` TIMESTAMP NULL COMMENT 'The time in which this Enrollment was started',
# 	`affirmedAt` TIMESTAMP NULL COMMENT 'The time in which this Enrollment was affirmed',
# 	`completedAt` TIMESTAMP NULL COMMENT 'time the Enrollment was completed and just before the certificates service call',
# 	`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP,
# 	`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record',
# 	`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP,
# 	`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record',
# 	PRIMARY KEY (`enrollmentId`)
# )COMMENT='The instance of a Person launching an Offering' ENGINE=InnoDB DEFAULT CHARSET=utf8mb3
#
#
#
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********
# ********

# %%
table_names
# Out:
# ['enrollmentdetailactivitystatus',
#  'enrollmentdetailcalendars',
#  'enrollmentdetaildownloads',
#  'enrollmentdetailhighlights',
#  'enrollmentdetaillinks',
#  'enrollmentdetailnodeadaptiveratings',
#  'enrollmentdetailnodepoints',
#  'enrollmentdetailnodequestionbookmarknotes',
#  'enrollmentdetailnodequestionstatistics',
#  'enrollmentdetailnodestatistics',
#  'enrollmentdetailactivitystatus',
#  'enrollmentdetailcalendars',
#  'enrollmentdetaildownloads',
#  'enrollmentdetailhighlights',
#  'enrollmentdetaillinks',
#  'enrollmentdetailnodeadaptiveratings',
#  'enrollmentdetailnodepoints',
#  'enrollmentdetailnodequestionbookmarknotes',
#  'enrollmentdetailnodequestionstatistics',
#  'enrollmentdetailnodestatistics',
#  '_archive_enrollmentdetailtokens',
#  '_archive_enrollments',
#  '_archive_instructorenrollments',
#  '_archive_personevents',
#  '_archive_personsecurityanswers',
#  '_archive_securitychallengeresponses',
#  '_archive_securitychallenges',
#  '_archive_securityquestions',
#  '_archive_testansweressaymedia',
#  '_archive_testansweressays',
#  'enrollmentdetailactivitystatus',
#  'enrollmentdetailcalendars',
#  'enrollmentdetaildownloads',
#  'enrollmentdetailhighlights',
#  'enrollmentdetaillinks',
#  'enrollmentdetailnodeadaptiveratings',
#  'enrollmentdetailnodepoints',
#  'enrollmentdetailnodequestionbookmarknotes',
#  'enrollmentdetailnodequestionstatistics',
#  'enrollmentdetailnodestatistics',
#  'enrollmentdetailactivitystatus',
#  'enrollmentdetailcalendars',
#  'enrollmentdetaildownloads',
#  'enrollmentdetailhighlights',
#  'enrollmentdetaillinks',
#  'enrollmentdetailnodeadaptiveratings',
#  'enrollmentdetailnodepoints',
#  'enrollmentdetailnodequestionbookmarknotes',
#  'enrollmentdetailnodequestionstatistics',
#  'enrollmentdetailnodestatistics',
#  '_archive_enrollmentdetailtokens',
#  '_archive_enrollments',
#  '_archive_instructorenrollments',
#  '_archive_personevents',
#  '_archive_personsecurityanswers',
#  '_archive_securitychallengeresponses',
#  '_archive_securitychallenges',
#  '_archive_securityquestions',
#  '_archive_testansweressaymedia',
#  '_archive_testansweressays',
#  'enrollmentdetailnodestatus',
#  'enrollmentdetailnodetimes',
#  'enrollmentdetails',
#  'enrollmentdetailsettings',
#  'enrollmentdetailtokens',
#  'enrollmentdetailucmsstatistics',
#  'enrollmentdetailvideochannels',
#  'enrollmentdetailvouchers',
#  'enrollmentportalcodes',
#  'enrollments',
#  'enrollmentdetailactivitystatus',
#  'enrollmentdetailcalendars',
#  'enrollmentdetaildownloads',
#  'enrollmentdetailhighlights',
#  'enrollmentdetaillinks',
#  'enrollmentdetailnodeadaptiveratings',
#  'enrollmentdetailnodepoints',
#  'enrollmentdetailnodequestionbookmarknotes',
#  'enrollmentdetailnodequestionstatistics',
#  'enrollmentdetailnodestatistics',
#  'enrollmentdetailactivitystatus',
#  'enrollmentdetailcalendars',
#  'enrollmentdetaildownloads',
#  'enrollmentdetailhighlights',
#  'enrollmentdetaillinks',
#  'enrollmentdetailnodeadaptiveratings',
#  'enrollmentdetailnodepoints',
#  'enrollmentdetailnodequestionbookmarknotes',
#  'enrollmentdetailnodequestionstatistics',
#  'enrollmentdetailnodestatistics',
#  '_archive_enrollmentdetailtokens',
#  '_archive_enrollments',
#  '_archive_instructorenrollments',
#  '_archive_personevents',
#  '_archive_personsecurityanswers',
#  '_archive_securitychallengeresponses',
#  '_archive_securitychallenges',
#  '_archive_securityquestions',
#  '_archive_testansweressaymedia',
#  '_archive_testansweressays',
#  'enrollmentdetailactivitystatus',
#  'enrollmentdetailcalendars',
#  'enrollmentdetaildownloads',
#  'enrollmentdetailhighlights',
#  'enrollmentdetaillinks',
#  'enrollmentdetailnodeadaptiveratings',
#  'enrollmentdetailnodepoints',
#  'enrollmentdetailnodequestionbookmarknotes',
#  'enrollmentdetailnodequestionstatistics',
#  'enrollmentdetailnodestatistics',
#  'enrollmentdetailactivitystatus',
#  'enrollmentdetailcalendars',
#  'enrollmentdetaildownloads',
#  'enrollmentdetailhighlights',
#  'enrollmentdetaillinks',
#  'enrollmentdetailnodeadaptiveratings',
#  'enrollmentdetailnodepoints',
#  'enrollmentdetailnodequestionbookmarknotes',
#  'enrollmentdetailnodequestionstatistics',
#  'enrollmentdetailnodestatistics',
#  '_archive_enrollmentdetailtokens',
#  '_archive_enrollments',
#  '_archive_instructorenrollments',
#  '_archive_personevents',
#  '_archive_personsecurityanswers',
#  '_archive_securitychallengeresponses',
#  '_archive_securitychallenges',
#  '_archive_securityquestions',
#  '_archive_testansweressaymedia',
#  '_archive_testansweressays',
#  'enrollmentdetailnodestatus',
#  'enrollmentdetailnodetimes',
#  'enrollmentdetails',
#  'enrollmentdetailsettings',
#  'enrollmentdetailtokens',
#  'enrollmentdetailucmsstatistics',
#  'enrollmentdetailvideochannels',
#  'enrollmentdetailvouchers',
#  'enrollmentportalcodes',
#  'enrollments']

# %%
# Extract table names from the relevant chunks
table_names = []
for chunk in relevant_chunks:  # Iterate through each chunk
    for line in chunk.split("\n"):  # Split each chunk into lines
        if line.strip().startswith("CREATE TABLE"):  # Find lines defining tables
            table_name = line.split()[2].strip("`")  # Extract table name (strip backticks)
            table_names.append(table_name)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 4
#       2 table_names = []
#       3 for chunk in relevant_chunks:  # Iterate through each chunk
# ----> 4     for line in chunk.split("\n"):  # Split each chunk into lines
#       5         if line.strip().startswith("CREATE TABLE"):  # Find lines defining tables
#       6             table_name = line.split()[2].strip("`")  # Extract table name (strip backticks)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
from langchain_experimental.sql import SQLDatabaseChain
db_chain = SQLDatabaseChain.from_llm(llm, relevant_db, verbose=True)
response = db_chain(query_text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 from langchain_experimental.sql import SQLDatabaseChain
# ----> 2 db_chain = SQLDatabaseChain.from_llm(llm, relevant_db, verbose=True)
#       3 response = db_chain(query_text)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_experimental\sql\base.py:229, in SQLDatabaseChain.from_llm(cls, llm, db, prompt, **kwargs)
#     210 @classmethod
#     211 def from_llm(
#     212     cls,
#    (...)
#     216     **kwargs: Any,
#     217 ) -> SQLDatabaseChain:
#     218     """Create a SQLDatabaseChain from an LLM and a database connection.
#     219
#     220     *Security note*: Make sure that the database connection uses credentials
#    (...)
#     227         https://github.com/langchain-ai/langchain/issues/5923
#     228     """
# --> 229     prompt = prompt or SQL_PROMPTS.get(db.dialect, PROMPT)
#     230     llm_chain = LLMChain(llm=llm, prompt=prompt)
#     231     return cls(llm_chain=llm_chain, database=db, **kwargs)
#
# AttributeError: 'str' object has no attribute 'dialect'

# %%
from langchain.utilities import SQLDatabase

# Extract table names from relevant chunks (assuming the schema contains table names)
table_names = []
for chunk in relevant_chunks:  # Iterate through the list of chunk strings
    for line in chunk.split("\n"):  # Split each chunk into lines
        if line.strip().startswith("CREATE TABLE"):  # Check if the line defines a table
            table_name = line.split()[2]  # Extract the table name
            table_names.append(table_name)

print("Extracted Table Names:", table_names)

# Filter the database schema for only relevant tables
relevant_db_schema = {table: db.get_table_info(table) for table in table_names}

# Create a new SQLDatabase instance for only relevant tables
relevant_db = SQLDatabase.from_schema(relevant_db_schema)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 6
#       4 table_names = []
#       5 for chunk in relevant_chunks:  # Iterate through the list of chunk strings
# ----> 6     for line in chunk.split("\n"):  # Split each chunk into lines
#       7         if line.strip().startswith("CREATE TABLE"):  # Check if the line defines a table
#       8             table_name = line.split()[2]  # Extract the table name
#
# AttributeError: 'list' object has no attribute 'split'

# %%
# Step 1: Embed the user's query
query = "How many unique start dates in enrollment detail calendars?"
query_embedding = model.encode(query)  # Use the same model as during insertion

# Step 2: Query the collection for top relevant chunks
results = collection.query(
    query_embeddings=[query_embedding],
    n_results=3  # Retrieve top 3 relevant chunks
)

# Step 3: Extract relevant chunks and metadata
relevant_chunks = results["documents"]  # List of top chunk descriptions
metadata = results["metadatas"]  # Metadata associated with the chunks

# %%
relevant_chunks
# Out:
# [["CREATE TABLE enrollmentdetailactivitystatus (\n\t`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment Detail to which the activity was assigned', \n\t`activityId` INTEGER UNSIGNED NOT NULL COMMENT 'Activity that was completed', \n\t`isComplete` TINYINT(1) NOT NULL COMMENT 'Whether the activity is completed' DEFAULT '0', \n\t`markedForReview` TINYINT(1) NOT NULL COMMENT 'Whether the activity is marked for review' DEFAULT '0', \n\t`completedAt` TIMESTAMP NULL COMMENT 'time the activity was completed', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\tPRIMARY KEY (`enrollmentDetailId`, `activityId`)\n)COMMENT='Activities completed in an Enrollment Detail' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE enrollmentdetailcalendars (\n\t`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that owns the assigned Calendar', \n\t`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar assigned to the EnrollmentDetail', \n\t`startDate` DATE NOT NULL COMMENT 'date the Calendar starts', \n\t`endDate` DATE NOT NULL COMMENT 'date the Calendar ends', \n\thash CHAR(32) COMMENT 'Hash of calendar setting during activity schedule', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\tPRIMARY KEY (`enrollmentDetailId`)\n)COMMENT='Ties a single EnrollmentDetail to a single Calendar' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE enrollmentdetaildownloads (\n\t`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment detail that was downloaded', \n\t`userAgentId` INTEGER NOT NULL COMMENT 'User agent Id', \n\tip INTEGER UNSIGNED NOT NULL COMMENT 'IP address' DEFAULT '0', \n\t`downloadCount` TINYINT UNSIGNED COMMENT 'Count of successful download attempts' DEFAULT '0', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\tPRIMARY KEY (`enrollmentDetailId`, `userAgentId`, ip)\n)COMMENT='Stores the count of downloads of an offline offeringDetail' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE enrollmentdetailhighlights (\n\t`enrollmentDetailId` INTEGER NOT NULL COMMENT 'EnrollmentDetail that the highlights apply to', \n\t`testId` INTEGER UNSIGNED NOT NULL COMMENT 'testId of the highlights, optional field', \n\t`key` VARCHAR(100) NOT NULL COMMENT 'Key name for data', \n\tvalue VARCHAR(255) NOT NULL COMMENT 'Page param value', \n\t`range` VARCHAR(500) NOT NULL COMMENT 'highlighted text range', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'Time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'Time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'PersonId of the account that last updated the record', \n\tPRIMARY ...
#   "CREATE TABLE _archive_calendaroffdates (\n\t`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar that requires specific off dates from scheduled tasks', \n\t`calendarOffDateRepeatTypeId` TINYINT UNSIGNED NOT NULL DEFAULT '1', \n\t`offDate` DATE NOT NULL COMMENT 'specific off date requested from scheduled tasks', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\t`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (`calendarId`, `calendarOffDateRepeatTypeId`, `offDate`)\n)COMMENT='Specific off dates requested from having tasks by Calendar' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE _archive_calendars (\n\t`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'surrogate primary key', \n\t`personId` INTEGER UNSIGNED NOT NULL COMMENT 'PersonAccount that owns the Calendar', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\t`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (`calendarId`)\n)COMMENT='Container to organize a collection of PersonEvents' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE _archive_enrollmentdetailcalendars (\n\t`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'EnrollmentDetail that owns the assigned Calendar', \n\t`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar assigned to the EnrollmentDetail', \n\t`startDate` DATE NOT NULL COMMENT 'date the Calendar starts', \n\t`endDate` DATE NOT NULL COMMENT 'date the Calendar ends', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\t`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (`enrollmentDetailId`)\n)COMMENT='Ties a single EnrollmentDetail to a single Calendar' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE _archive_enrollmentdetaildownloads (\n\t`enrollmentDetailId` INTEGER UNSIGNED NOT NULL COMMENT 'Enrollment detail that was downloaded', \n\t`userAgentId` INTEGER NOT NULL COMMENT 'User agent Id', \n\tip INTEGER UNSIGNED NOT NULL COMMENT 'IP address' DEFAULT '0', \n\t`downloadCount` TINYINT UNSIGNED COMMENT 'Count of successful download attempts' DEFAULT '0', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\t`archivedAt` TIMESTAMP NOT NULL COMMENT 'time the record was archived' DEFAULT CURRENT_TIMESTAMP, \n\tPRIMARY KEY (`enrollmentDetailId`, `userAgentId`, ip)\n)COMMENT='Stores the count of ...
#   "CREATE TABLE personevents (\n\t`personEventId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT, \n\t`calendarId` INTEGER UNSIGNED NOT NULL COMMENT 'Calendar the PersonEvent belongs to', \n\t`nodeId` INTEGER UNSIGNED NOT NULL COMMENT 'task type Node for the PersonEvent', \n\t`startTime` TIMESTAMP NOT NULL COMMENT 'time the PersonEvent starts' DEFAULT CURRENT_TIMESTAMP, \n\t`durationSeconds` MEDIUMINT UNSIGNED NOT NULL COMMENT 'duration in seconds of the PersonEvent' DEFAULT '0', \n\ttitle VARCHAR(255) NOT NULL COMMENT 'title of the PersonEvent', \n\t`shortTitle` VARCHAR(30) COMMENT 'A shortened title for the PersonEvent', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\tPRIMARY KEY (`personEventId`)\n)COMMENT='Calendar of tasks and custom events by PersonAccount' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE personforumsettings (\n\t`personId` INTEGER UNSIGNED NOT NULL COMMENT 'Person', \n\t`displayName` VARCHAR(50) NOT NULL COMMENT 'Forum display name', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\tPRIMARY KEY (`personId`)\n)COMMENT='Person forum settings' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE personnotifications (\n\t`personNotificationId` INTEGER UNSIGNED NOT NULL COMMENT 'Auto-incrementing surrogate primary key' AUTO_INCREMENT, \n\t`personId` INTEGER UNSIGNED NOT NULL COMMENT 'PersonAccount to whom the Notification is sent', \n\t`notificationId` INTEGER UNSIGNED NOT NULL COMMENT 'Notification ID', \n\t`isRead` TINYINT UNSIGNED NOT NULL COMMENT 'has the notification been read?' DEFAULT '0', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\tPRIMARY KEY (`personNotificationId`)\n)COMMENT='List of Notifications by PersonAccount' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE personofferinggroupsettings (\n\t`personId` INTEGER UNSIGNED NOT NULL COMMENT 'Person', \n\t`offeringGroup` VARCHAR(255) NOT NULL COMMENT 'Offering group', \n\t`dashboardViewId` TINYINT UNSIGNED NOT NULL COMMENT 'Default dashboard view' DEFAULT '1', \n\t`myProgressToggleFlag` TINYINT(1) NOT NULL DEFAULT '1', \n\t`createdAt` TIMESTAMP NOT NULL COMMENT 'time the record was created' DEFAULT CURRENT_TIMESTAMP, \n\t`createdBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that created the record', \n\t`updatedAt` TIMESTAMP NOT NULL COMMENT 'time the record was last updated' DEFAULT CURRENT_TIMESTAMP ON UPDATE CURRENT_TIMESTAMP, \n\t`updatedBy` INTEGER UNSIGNED NOT NULL COMMENT 'personId of the account that last updated the record', \n\tPRIMARY KEY (`personId`, `offeringGroup`)\n)COMMENT='Person offering group settings' DEFAULT CHARSET=utf8mb3 ENGINE=InnoDB\n\n CREATE TABLE personpasswordresettokens (\n\t`personId` INTEGER UNSIGNED NOT NULL COMMENT 'Foreign key to the PersonAccounts table', \n\ttoken CHAR(32 ...

# %%
# Example: Embed and insert chunks into the collection
table_metadata = db.table_info  # Assume db.table_info is a list of table descriptions
table_chunks = [table_metadata[i:i + 20] for i in range(0, len(table_metadata), 20)]

for idx, chunk in enumerate(table_chunks):
    chunk_description = " ".join(chunk)  # Convert chunk metadata to string
    embedding = model.encode(chunk_description)  # Generate embedding
    
    # Add to the ChromaDB collection
    collection.add(
        ids=[f"chunk_{idx}"],  # Unique ID for each chunk
        documents=[chunk_description],  # Document data
        metadatas=[{"chunk_id": idx}],  # Metadata associated with the document
        embeddings=[embedding]  # Embedding vector
    )

# %%
metadata
# Out:
# [[{'chunk_id': 1599}, {'chunk_id': 8903}, {'chunk_id': 3153}]]

# %%
def get_relevant_chunks(query, top_k=3):
    query_embedding = model.encode(query)
    results = chroma_client.query(
        collection_name="table_embeddings",
        query_embeddings=[query_embedding],
        n_results=top_k
    )
    return results["documents"], results["metadatas"]

# Example Query
query = "How many unique start dates in enrollment detail calendars?"
relevant_chunks, metadata = get_relevant_chunks(query)

# %%
from sentence_transformers import SentenceTransformer
import chromadb
from chromadb.config import Settings

# Load table names
tables = db.get_table_names()

# Split tables into chunks of specified size
chunk_size = 20
chunks = [tables[i:i + chunk_size] for i in range(0, len(tables), chunk_size)]

# Load embedding model
MODEL_NAME = "all-mpnet-base-v2"
embedding_model = SentenceTransformer(MODEL_NAME)

# Initialize ChromaDB client with persistence
CHROMA_DB_DIR = "chroma_db"  # Directory to store the Chroma database
COLLECTION_NAME = "db_embeddings"
client = chromadb.Client(Settings(persist_directory=CHROMA_DB_DIR))

# Get or create the collection
if COLLECTION_NAME not in client.list_collections():
    collection = client.create_collection(name=COLLECTION_NAME)
else:
    collection = client.get_collection(name=COLLECTION_NAME)
# Out:
# WARNING:tensorflow:From C:\Users\keert\AppData\Local\Programs\Python\Python311\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# C:\Users\keert\AppData\Local\Temp\ipykernel_23588\835300533.py:6: LangChainDeprecationWarning: The method `SQLDatabase.get_table_names` was deprecated in langchain-community 0.0.1 and will be removed in 1.0. Use :meth:`~get_usable_table_names` instead.
#   tables = db.get_table_names()

# %%
# Add each chunk's metadata to ChromaDB
for i, chunk in enumerate(chunks):
    # Convert the list of table names to a single string
    chunk_metadata = ", ".join(chunk)  # Join table names with commas
    
    # Encode metadata to generate embeddings
    # Convert the embedding to a Python list of floats
    chunk_embedding = embedding_model.encode([chunk_metadata]).tolist()  # Ensure embedding is a list of lists
    
    # Add the document and embedding to the collection
    collection.add(
        documents=[chunk_metadata],
        embeddings=[chunk_embedding],  # This is now a list of lists of floats
        metadatas=[{"chunk_id": i, "tables": chunk_metadata}],
        ids=[f"chunk_{i}"]
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      89 try:
# ---> 90     return func(self, *args, **kwargs)
#      91 except Exception as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:197, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     181 @validation_context("add")
#     182 def _validate_and_prepare_add_request(
#     183     self,
#    (...)
#     195 ) -> AddRequest:
#     196     # Unpack
# --> 197     add_records = normalize_insert_record_set(
#     198         ids=ids,
#     199         embeddings=embeddings,
#     200         metadatas=metadatas,
#     201         documents=documents,
#     202         images=images,
#     203         uris=uris,
#     204     )
#     206     # Validate
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\types.py:181, in normalize_insert_record_set(ids, embeddings, metadatas, documents, images, uris)
#     178 """
#     179 Unpacks and normalizes the fields of an InsertRecordSet.
#     180 """
# --> 181 base_record_set = normalize_base_record_set(
#     182     embeddings=embeddings, documents=documents, images=images, uris=uris
#     183 )
#     185 return InsertRecordSet(
#     186     ids=cast(IDs, maybe_cast_one_to_many(ids)),
#     187     metadatas=maybe_cast_one_to_many(metadatas),
#    (...)
#     191     uris=base_record_set["uris"],
#     192 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\types.py:158, in normalize_base_record_set(embeddings, documents, images, uris)
#     153 """
#     154 Unpacks and normalizes the fields of a BaseRecordSet.
#     155 """
#     157 return BaseRecordSet(
# --> 158     embeddings=normalize_embeddings(embeddings),
#     159     documents=maybe_cast_one_to_many(documents),
#     160     images=maybe_cast_one_to_many(images),
#     161     uris=maybe_cast_one_to_many(uris),
#     162 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\types.py:82, in normalize_embeddings(target)
#      80         return list(target)
# ---> 82 raise ValueError(
#      83     f"Expected embeddings to be a list of floats or ints, a list of lists, a numpy array, or a list of numpy arrays, got {target}"
#      84 )
#
# ValueError: Expected embeddings to be a list of floats or ints, a list of lists, a numpy array, or a list of numpy arrays, got [[[0.0386556051671505, 0.11184519529342651, -0.006736932322382927, 0.03807051107287407, -0.028034543618559837, 0.07057534158229828, 0.01893794909119606, 0.05495923012495041, 0.02034028246998787, 0.014391043223440647, 0.06287868320941925, 0.027452755719423294, -0.0014603276504203677, 0.01125366147607565, -0.09839293360710144, -0.007613564375787973, 0.017993539571762085, 0.007028432097285986, -0.03173493593931198, -0.040938571095466614, -0.08365282416343689, 0.05022992938756943, -0.0030546924099326134, 0.00851756427437067, 0.0665421113371849, -0.00481359614059329, -0.014780145138502121, 0.0034110744018107653, -0.03785569593310356, -0.06007940322160721, 0.044797807931900024, -0.021176613867282867, -0.001275033107958734, -0.01153192762285471, 1.8206989125246764e-06, -0.029277581721544266, -0.032435186207294464, -0.007604002952575684, -0.10694392025470734, 0.04492250457406044, 0.012423619627952576, 0.04045836627483368, -0.03668443113565445, -0.029484948143363, 0.0006967282970435917, -0.013656564988195896, -0.00700371852144599, 0.023860560730099678, -0.03499980643391609, 0.05901513621211052, 0.02878267504274845, -0.0027619146276265383, 0.008269957266747952, -0.09023582935333252, 0.05723622441291809, -0.017277104780077934, 0.0007068515405990183, -0.011574004776775837, -0.026829829439520836, 0.05122439190745354, 0.001660047797486186, -0.009001598693430424, 0.006454707123339176, -0.0034707358572632074, 0.005655866116285324, 0.01219959370791912, 0.027422059327363968, -0.024674220010638237, 0.07097192108631134, -0.04452436789870262, 0.08119384944438934, -0.016194112598896027, 0.04090845212340355, 0.07367115467786789, -0.04156928509473801, 0.012253337539732456, -0.02414446510374546, 0.01856662705540657, 0.00569365406408906, -0.01964772306382656, -0.02038443647325039, 0.030902044847607613, -0.007618749048560858, 0.008193244226276875, 0.015942905098199844, 0.015706786885857582, -0.01914411224424839, 0.0009352965280413628, 0.021700305864214897, -0.07134006172418594, 0.0745418593287468, -0.015290018171072006, -0.0023247571662068367, 0.02867765538394451, 0.07618553936481476, -0.031138470396399498, -0.03802591189742088, 0.0063799405470490456, 0.03655767813324928, 0.039315029978752136, -0.01273068506270647, -0.006696621421724558, -0.002406817628070712, 0.019027622416615486, -0.03543727472424507, 0.05891205742955208, 0.04118003696203232, -0.013072901405394077, 0.010270929895341396, 0.04940497875213623, 0.027948515489697456, 0.01965695060789585, -0.03818439692258835, 0.024122120812535286, -0.020610809326171875, 0.03935147821903229, -0.021952234208583832, -0.03669145703315735, 0.04102173447608948, 0.02936621941626072, 0.023521175608038902, -0.00955751072615385, -0.02597876451909542, 0.005238813813775778, -0.03538142144680023, -0.05862969532608986, -0.013387557119131088, -0.029027840122580528, 0.006380611564964056, -0.03333393484354019, -0.012517047114670277, 0.0007082133088260889, 0.010397144593298435, -0.005039730109274387, 0.009074528701603413, -0.006347108166664839, 0.028210805729031563, -0.01497689075767994, -0.03530220314860344, -0.056977201253175735, 0.05913032218813896, 0.029252834618091583, 0.013169912621378899, -0.022188346832990646, 0.016473891213536263, -0.018018627539277077, 0.046277403831481934, -0.024185635149478912, 0.0025175870396196842, -0.014065946452319622, -0.07648198306560516, 0.00025438962620683014, 0.003749106079339981, 0.009904681704938412, 0.0518670491874218, 0.022052250802516937, 0.07146217674016953, -0.07468192279338837, -0.01023903675377369, 0.06130916252732277, 0.010311562567949295, -0.011433611623942852, 0.023004602640867233, -0.036718398332595825, -0.008900703862309456, -0.03550087660551071, 0.01531392615288496, -0.017985092476010323, -0.018519213423132896, -0.028896130621433258, -0.01966102421283722, 0.03627793490886688, 0.0006339746760204434, -0.0455034077167511, -0.0595284141600132, 0.05266 ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 11
#       8 chunk_embedding = embedding_model.encode([chunk_metadata]).tolist()  # Ensure embedding is a list of lists
#      10 # Add the document and embedding to the collection
# ---> 11 collection.add(
#      12     documents=[chunk_metadata],
#      13     embeddings=[chunk_embedding],  # This is now a list of lists of floats
#      14     metadatas=[{"chunk_id": i, "tables": chunk_metadata}],
#      15     ids=[f"chunk_{i}"]
#      16 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\Collection.py:81, in Collection.add(self, ids, embeddings, metadatas, documents, images, uris)
#      46 def add(
#      47     self,
#      48     ids: OneOrMany[ID],
#    (...)
#      58     uris: Optional[OneOrMany[URI]] = None,
#      59 ) -> None:
#      60     """Add embeddings to the data store.
#      61     Args:
#      62         ids: The ids of the embeddings you wish to add
#    (...)
#      78
#      79     """
# ---> 81     add_request = self._validate_and_prepare_add_request(
#      82         ids=ids,
#      83         embeddings=embeddings,
#      84         metadatas=metadatas,
#      85         documents=documents,
#      86         images=images,
#      87         uris=uris,
#      88     )
#      90     self._client._add(
#      91         collection_id=self.id,
#      92         ids=add_request["ids"],
#    (...)
#      98         database=self.database,
#      99     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:93, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      91 except Exception as e:
#      92     msg = f"{str(e)} in {name}."
# ---> 93     raise type(e)(msg).with_traceback(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:90, in validation_context.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      87 @functools.wraps(func)
#      88 def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      89     try:
# ---> 90         return func(self, *args, **kwargs)
#      91     except Exception as e:
#      92         msg = f"{str(e)} in {name}."
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\models\CollectionCommon.py:197, in CollectionCommon._validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     181 @validation_context("add")
#     182 def _validate_and_prepare_add_request(
#     183     self,
#    (...)
#     195 ) -> AddRequest:
#     196     # Unpack
# --> 197     add_records = normalize_insert_record_set(
#     198         ids=ids,
#     199         embeddings=embeddings,
#     200         metadatas=metadatas,
#     201         documents=documents,
#     202         images=images,
#     203         uris=uris,
#     204     )
#     206     # Validate
#     207     validate_insert_record_set(record_set=add_records)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\types.py:181, in normalize_insert_record_set(ids, embeddings, metadatas, documents, images, uris)
#     165 def normalize_insert_record_set(
#     166     ids: OneOrMany[ID],
#     167     embeddings: Optional[
#    (...)
#     176     uris: Optional[OneOrMany[URI]] = None,
#     177 ) -> InsertRecordSet:
#     178     """
#     179     Unpacks and normalizes the fields of an InsertRecordSet.
#     180     """
# --> 181     base_record_set = normalize_base_record_set(
#     182         embeddings=embeddings, documents=documents, images=images, uris=uris
#     183     )
#     185     return InsertRecordSet(
#     186         ids=cast(IDs, maybe_cast_one_to_many(ids)),
#     187         metadatas=maybe_cast_one_to_many(metadatas),
#    (...)
#     191         uris=base_record_set["uris"],
#     192     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\types.py:158, in normalize_base_record_set(embeddings, documents, images, uris)
#     147 def normalize_base_record_set(
#     148     embeddings: Optional[Union[OneOrMany[Embedding], OneOrMany[PyEmbedding]]] = None,
#     149     documents: Optional[OneOrMany[Document]] = None,
#     150     images: Optional[OneOrMany[Image]] = None,
#     151     uris: Optional[OneOrMany[URI]] = None,
#     152 ) -> BaseRecordSet:
#     153     """
#     154     Unpacks and normalizes the fields of a BaseRecordSet.
#     155     """
#     157     return BaseRecordSet(
# --> 158         embeddings=normalize_embeddings(embeddings),
#     159         documents=maybe_cast_one_to_many(documents),
#     160         images=maybe_cast_one_to_many(images),
#     161         uris=maybe_cast_one_to_many(uris),
#     162     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\types.py:82, in normalize_embeddings(target)
#      79     if target.ndim == 2:
#      80         return list(target)
# ---> 82 raise ValueError(
#      83     f"Expected embeddings to be a list of floats or ints, a list of lists, a numpy array, or a list of numpy arrays, got {target}"
#      84 )
#
# ValueError: Expected embeddings to be a list of floats or ints, a list of lists, a numpy array, or a list of numpy arrays, got [[[0.0386556051671505, 0.11184519529342651, -0.006736932322382927, 0.03807051107287407, -0.028034543618559837, 0.07057534158229828, 0.01893794909119606, 0.05495923012495041, 0.02034028246998787, 0.014391043223440647, 0.06287868320941925, 0.027452755719423294, -0.0014603276504203677, 0.01125366147607565, -0.09839293360710144, -0.007613564375787973, 0.017993539571762085, 0.007028432097285986, -0.03173493593931198, -0.040938571095466614, -0.08365282416343689, 0.05022992938756943, -0.0030546924099326134, 0.00851756427437067, 0.0665421113371849, -0.00481359614059329, -0.014780145138502121, 0.0034110744018107653, -0.03785569593310356, -0.06007940322160721, 0.044797807931900024, -0.021176613867282867, -0.001275033107958734, -0.01153192762285471, 1.8206989125246764e-06, -0.029277581721544266, -0.032435186207294464, -0.007604002952575684, -0.10694392025470734, 0.04492250457406044, 0.012423619627952576, 0.04045836627483368, -0.03668443113565445, -0.029484948143363, 0.0006967282970435917, -0.013656564988195896, -0.00700371852144599, 0.023860560730099678, -0.03499980643391609, 0.05901513621211052, 0.02878267504274845, -0.0027619146276265383, 0.008269957266747952, -0.09023582935333252, 0.05723622441291809, -0.017277104780077934, 0.0007068515405990183, -0.011574004776775837, -0.026829829439520836, 0.05122439190745354, 0.001660047797486186, -0.009001598693430424, 0.006454707123339176, -0.0034707358572632074, 0.005655866116285324, 0.01219959370791912, 0.027422059327363968, -0.024674220010638237, 0.07097192108631134, -0.04452436789870262, 0.08119384944438934, -0.016194112598896027, 0.04090845212340355, 0.07367115467786789, -0.04156928509473801, 0.012253337539732456, -0.02414446510374546, 0.01856662705540657, 0.00569365406408906, -0.01964772306382656, -0.02038443647325039, 0.030902044847607613, -0.007618749048560858, 0.008193244226276875, 0.015942905098199844, 0.015706786885857582, -0.01914411224424839, 0.0009352965280413628, 0.021700305864214897, -0.07134006172418594, 0.0745418593287468, -0.015290018171072006, -0.0023247571662068367, 0.02867765538394451, 0.07618553936481476, -0.031138470396399498, -0.03802591189742088, 0.0063799405470490456, 0.03655767813324928, 0.039315029978752136, -0.01273068506270647, -0.006696621421724558, -0.002406817628070712, 0.019027622416615486, -0.03543727472424507, 0.05891205742955208, 0.04118003696203232, -0.013072901405394077, 0.010270929895341396, 0.04940497875213623, 0.027948515489697456, 0.01965695060789585, -0.03818439692258835, 0.024122120812535286, -0.020610809326171875, 0.03935147821903229, -0.021952234208583832, -0.03669145703315735, 0.04102173447608948, 0.02936621941626072, 0.023521175608038902, -0.00955751072615385, -0.02597876451909542, 0.005238813813775778, -0.03538142144680023, -0.05862969532608986, -0.013387557119131088, -0.029027840122580528, 0.006380611564964056, -0.03333393484354019, -0.012517047114670277, 0.0007082133088260889, 0.010397144593298435, -0.005039730109274387, 0.009074528701603413, -0.006347108166664839, 0.028210805729031563, -0.01497689075767994, -0.03530220314860344, -0.056977201253175735, 0.05913032218813896, 0.029252834618091583, 0.013169912621378899, -0.022188346832990646, 0.016473891213536263, -0.018018627539277077, 0.046277403831481934, -0.024185635149478912, 0.0025175870396196842, -0.014065946452319622, -0.07648198306560516, 0.00025438962620683014, 0.003749106079339981, 0.009904681704938412, 0.0518670491874218, 0.022052250802516937, 0.07146217674016953, -0.07468192279338837, -0.01023903675377369, 0.06130916252732277, 0.010311562567949295, -0.011433611623942852, 0.023004602640867233, -0.036718398332595825, -0.008900703862309456, -0.03550087660551071, 0.01531392615288496, -0.017985092476010323, -0.018519213423132896, -0.028896130621433258, -0.01966102421283722, 0.03627793490886688, 0.0006339746760204434, -0.0455034077167511, -0.0595284141600132, 0.05266 ...

# %%
# Function to print entire collection
def print_entire_collection(collection):
    # Retrieve all data from the collection with embeddings included
    data = collection.get(include=["embeddings", "documents", "metadatas"])
    
    # Print the retrieved data
    print("Collection Data:")
    print(data)

# Print the entire collection
print_entire_collection(collection)
# Out:
# Collection Data:
# {'ids': ['chunk_0', 'chunk_1', 'chunk_2', 'chunk_3', 'chunk_4', 'chunk_5', 'chunk_6', 'chunk_7', 'chunk_8', 'chunk_9', 'chunk_10', 'chunk_11', 'chunk_12'], 'embeddings': None, 'documents': ['_archive_calendaroffdates, _archive_calendars, _archive_enrollmentdetailcalendars, _archive_enrollmentdetaildownloads, _archive_enrollmentdetailnodepoints, _archive_enrollmentdetailnodequestionstatistics, _archive_enrollmentdetailnodestatistics, _archive_enrollmentdetailnodestatus, _archive_enrollmentdetailnodetimes, _archive_enrollmentdetails, _archive_enrollmentdetailtokens, _archive_enrollments, _archive_instructorenrollments, _archive_personevents, _archive_personsecurityanswers, _archive_securitychallengeresponses, _archive_securitychallenges, _archive_securityquestions, _archive_testansweressaymedia, _archive_testansweressays', '_archive_testanswers, _archive_testattributes, _archive_testlog, _archive_testquestions, _archive_tests, _archive_testsettings, _archive_testsoffline, _tmp_nodestatstimes, _tmp_parentstats, _tmp_test_values, _tmp_teststatusids, aclresources, aclroles, aclrolesgraph, aclrules, activities, activitygroupnoderoots, activitygroups, activitygrouptags, activitygrouptaskgroups', 'activitygrouptopics, activitylabels, activityperformancetopics, activitytags, activitytaskgroup, activitytopics, activitytopicweights, activitytypes, adaptiveperformancelabels, bookmarknotes, calendardaysoffgroups, calendarfixeddays, calendarfixeddaysgroups, calendarfixeddaysgrouptypes, calendargroupdaysoff, calendaroffdaterepeattypes, calendaroffdates, calendars, contentmedia, contentmodulelinks', 'contents, contenttypes, contentucms, dashboardviews, databasechangelog, databasechangeloglock, dimensionimporthistory, dimensionreferences, dimensions, dimensiontypes, discussionmedia, discussionmessages, discussionnodes, discussionofferings, discussionquestions, discussions, discussiontypes, domtest, enrollmentdetailactivitygrouptopics, enrollmentdetailactivitystatus', 'enrollmentdetailcalendars, enrollmentdetaildownloads, enrollmentdetailhighlights, enrollmentdetaillinks, enrollmentdetailnodeadaptiveratings, enrollmentdetailnodepoints, enrollmentdetailnodequestionbookmarknotes, enrollmentdetailnodequestionstatistics, enrollmentdetailnodestatistics, enrollmentdetailnodestatus, enrollmentdetailnodetimes, enrollmentdetails, enrollmentdetails-trav, enrollmentdetailsettings, enrollmentdetailtokens, enrollmentdetailucmsstatistics, enrollmentdetailvideochannels, enrollmentdetailvouchers, enrollmentportalcodes, enrollments', 'enrollmentsettings, enrollmentshistory, examweighting, examweightingnames, features, federationtokens, fixedtestquestions, fixedtests, folderrootfeatures, folderroots, folders, foldertypes, glossary, gradingscalescorerangedisplays, gradingscalescores, highlights, highlighttexts, highlighttypes, identifiersnotnowlogs, impersonatorlogs', 'importers, instructorenrollments, instructorlinkproductmessages, instructorsonline, media, mediasources, modulelinkpageparams, modulelinks, nodeattributes, nodeclassifications, nodedifficultystatistics, nodedimensionreferences, nodedimensions, nodedimensionshistory, nodegraph, noderoots, nodes, nodes_12052023_backup_dba, nodestatistics, nodestatistics_12052023_backup_dba', 'nodetagdifficultystatistics, nodetagstatistics, nodetaxonomy, nodetypes, notificationofferings, notifications, offeringdetailactivitygroups, offeringdetailclassifications, offeringdetailnoderoots, offeringdetails, offeringdetailsubtypes, offeringdetailtypes, offeringofferingdetails, offerings, personaccountaclroles, personaccounthistory, personaccounts, personaccounttokens, personactivities, personactivitiestrav', 'personevents, personforumsettings, personnotifications, personofferinggroupsettings, personpasswordresettokens, personsecurityanswers, proctorexamsites, proctoridentificationtypes, proctortrackonboardingstatuses, proctortrackstatuses, proctortrackteststatuses, questionassignments, questionattributes, questionblankansw ...

# %% [markdown]
# <h1>Query Handling</h1>

# %%
from langchain_experimental.sql import SQLDatabaseChain

def process_query(query_text, top_k=1):
    # Generate embedding for the query
    query_embedding = embedding_model.encode([query_text])
    
    # Perform query on ChromaDB
    results = collection.query(query_embeddings=query_embedding, n_results=top_k)
    
    # Extract relevant tables from metadata
    relevant_chunks = []
    for metadata in results["metadatas"]:
        if "tables" in metadata:
            relevant_chunks.extend(metadata["tables"])  # Assuming tables is a list
        else:
            print(f"Warning: 'tables' key missing in metadata: {metadata}")
    
    # Get unique tables
    relevant_tables = list(set(relevant_chunks))
    print(len( relevant_tables))
    
    # Load a new SQLDatabase instance with only the relevant tables
    relevant_db = SQLDatabase.from_uri(
        f"mysql+pymysql://{db_user}:{db_password}@{db_host}:{db_port}/{db_name}",
        include_tables=relevant_tables,
        sample_rows_in_table_info=0
    )
    
    # Execute query using the LLM and relevant database
    db_chain = SQLDatabaseChain.from_llm(llm, relevant_db, verbose=True)
    response = db_chain(query_text)
    return response

# %%
query = "How many unique start dates are in the enrollmentdetailcalendars?"
result = process_query(query)
print(result)
# Out:
# Warning: 'tables' key missing in metadata: [{'chunk_id': 4, 'tables': 'enrollmentdetailcalendars, enrollmentdetaildownloads, enrollmentdetailhighlights, enrollmentdetaillinks, enrollmentdetailnodeadaptiveratings, enrollmentdetailnodepoints, enrollmentdetailnodequestionbookmarknotes, enrollmentdetailnodequestionstatistics, enrollmentdetailnodestatistics, enrollmentdetailnodestatus, enrollmentdetailnodetimes, enrollmentdetails, enrollmentdetails-trav, enrollmentdetailsettings, enrollmentdetailtokens, enrollmentdetailucmsstatistics, enrollmentdetailvideochannels, enrollmentdetailvouchers, enrollmentportalcodes, enrollments'}]
# 0
#
#
# > Entering new SQLDatabaseChain chain...
# How many unique start dates are in the enrollmentdetailcalendars?
# SQLQuery:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[18], line 2
#       1 query = "How many unique start dates are in the enrollmentdetailcalendars?"
# ----> 2 result = process_query(query)
#       3 print(result)
#
# Cell In[17], line 31, in process_query(query_text, top_k)
#      29 # Execute query using the LLM and relevant database
#      30 db_chain = SQLDatabaseChain.from_llm(llm, relevant_db, verbose=True)
# ---> 31 response = db_chain(query_text)
#      32 return response
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_experimental\sql\base.py:204, in SQLDatabaseChain._call(self, inputs, run_manager)
#     200 except Exception as exc:
#     201     # Append intermediate steps to exception, to aid in logging and later
#     202     # improvement of few shot prompt seeds
#     203     exc.intermediate_steps = intermediate_steps  # type: ignore
# --> 204     raise exc
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_experimental\sql\base.py:133, in SQLDatabaseChain._call(self, inputs, run_manager)
#     131 try:
#     132     intermediate_steps.append(llm_inputs.copy())  # input: sql generation
# --> 133     sql_cmd = self.llm_chain.predict(
#     134         callbacks=_run_manager.get_child(),
#     135         **llm_inputs,
#     136     ).strip()
#     137     if self.return_sql:
#     138         return {self.output_key: sql_cmd}
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:318, in LLMChain.predict(self, callbacks, **kwargs)
#     303 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     304     """Format prompt with kwargs and pass to LLM.
#     305
#     306     Args:
#    (...)
#     316             completion = llm.predict(adjective="funny")
#     317     """
# --> 318     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_groq\chat_models.py:474, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     469 message_dicts, params = self._create_message_dicts(messages, stop)
#     470 params = {
#     471     **params,
#     472     **kwargs,
#     473 }
# --> 474 response = self.client.create(messages=message_dicts, **params)
#     475 return self._create_chat_result(response)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\groq\resources\chat\completions.py:298, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     157 def create(
#     158     self,
#     159     *,
#    (...)
#     186     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     188     """
#     189     Creates a model response for the given chat conversation.
#     190
#    (...)
#     296       timeout: Override the client-level default timeout for this request, in seconds
#     297     """
# --> 298     return self._post(
#     299         "/openai/v1/chat/completions",
#     300         body=maybe_transform(
#     301             {
#     302                 "messages": messages,
#     303                 "model": model,
#     304                 "frequency_penalty": frequency_penalty,
#     305                 "function_call": function_call,
#     306                 "functions": functions,
#     307                 "logit_bias": logit_bias,
#     308                 "logprobs": logprobs,
#     309                 "max_tokens": max_tokens,
#     310                 "n": n,
#     311                 "parallel_tool_calls": parallel_tool_calls,
#     312                 "presence_penalty": presence_penalty,
#     313                 "response_format": response_format,
#     314                 "seed": seed,
#     315                 "stop": stop,
#     316                 "stream": stream,
#     317                 "temperature": temperature,
#     318                 "tool_choice": tool_choice,
#     319                 "tools": tools,
#     320                 "top_logprobs": top_logprobs,
#     321                 "top_p": top_p,
#     322                 "user": user,
#     323             },
#     324             completion_create_params.CompletionCreateParams,
#     325         ),
#     326         options=make_request_options(
#     327             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     328         ),
#     329         cast_to=ChatCompletion,
#     330         stream=stream or False,
#     331         stream_cls=Stream[ChatCompletionChunk],
#     332     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\groq\_base_client.py:1261, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1247 def post(
#    1248     self,
#    1249     path: str,
#    (...)
#    1256     stream_cls: type[_StreamT] | None = None,
#    1257 ) -> ResponseT | _StreamT:
#    1258     opts = FinalRequestOptions.construct(
#    1259         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1260     )
# -> 1261     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\groq\_base_client.py:953, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     950 else:
#     951     retries_taken = 0
# --> 953 return self._request(
#     954     cast_to=cast_to,
#     955     options=options,
#     956     stream=stream,
#     957     stream_cls=stream_cls,
#     958     retries_taken=retries_taken,
#     959 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\groq\_base_client.py:1056, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1053         err.response.read()
#    1055     log.debug("Re-raising status error")
# -> 1056     raise self._make_status_error_from_response(err.response) from None
#    1058 return self._process_response(
#    1059     cast_to=cast_to,
#    1060     options=options,
#    (...)
#    1064     retries_taken=retries_taken,
#    1065 )
#
# APIStatusError: Error code: 413 - {'error': {'message': 'Request too large for model `llama-3.3-70b-versatile` in organization `org_01jdb5bnksfzt803m2mpy97p1m` on tokens per minute (TPM): Limit 6000, Requested 58953, please reduce your message size and try again. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}

# %%
from langchain_experimental.sql import SQLDatabaseChain

db_chain = SQLDatabaseChain.from_llm(llm, db,verbose=True)
qns1 = db_chain("how many unique startdate in enrollmentdetailcalendars")
# Out:
# > Entering new SQLDatabaseChain chain...
# how many unique startdate in enrollmentdetailcalendars
# SQLQuery:
# ---------------------------------------------------------------------------
# APIStatusError                            Traceback (most recent call last)
# Cell In[27], line 4
#       1 from langchain_experimental.sql import SQLDatabaseChain
#       3 db_chain = SQLDatabaseChain.from_llm(llm, db,verbose=True)
# ----> 4 qns1 = db_chain("how many unique startdate in enrollmentdetailcalendars")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_experimental\sql\base.py:204, in SQLDatabaseChain._call(self, inputs, run_manager)
#     200 except Exception as exc:
#     201     # Append intermediate steps to exception, to aid in logging and later
#     202     # improvement of few shot prompt seeds
#     203     exc.intermediate_steps = intermediate_steps  # type: ignore
# --> 204     raise exc
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_experimental\sql\base.py:133, in SQLDatabaseChain._call(self, inputs, run_manager)
#     131 try:
#     132     intermediate_steps.append(llm_inputs.copy())  # input: sql generation
# --> 133     sql_cmd = self.llm_chain.predict(
#     134         callbacks=_run_manager.get_child(),
#     135         **llm_inputs,
#     136     ).strip()
#     137     if self.return_sql:
#     138         return {self.output_key: sql_cmd}
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:318, in LLMChain.predict(self, callbacks, **kwargs)
#     303 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     304     """Format prompt with kwargs and pass to LLM.
#     305
#     306     Args:
#    (...)
#     316             completion = llm.predict(adjective="funny")
#     317     """
# --> 318     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\_api\deprecation.py:182, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     180     warned = True
#     181     emit_warning()
# --> 182 return wrapped(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:389, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     357 """Execute the chain.
#     358
#     359 Args:
#    (...)
#     380         `Chain.output_keys`.
#     381 """
#     382 config = {
#     383     "callbacks": callbacks,
#     384     "tags": tags,
#     385     "metadata": metadata,
#     386     "run_name": run_name,
#     387 }
# --> 389 return self.invoke(
#     390     inputs,
#     391     cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#     392     return_only_outputs=return_only_outputs,
#     393     include_run_info=include_run_info,
#     394 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:170, in Chain.invoke(self, input, config, **kwargs)
#     168 except BaseException as e:
#     169     run_manager.on_chain_error(e)
# --> 170     raise e
#     171 run_manager.on_chain_end(outputs)
#     173 if include_run_info:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\base.py:160, in Chain.invoke(self, input, config, **kwargs)
#     157 try:
#     158     self._validate_inputs(inputs)
#     159     outputs = (
# --> 160         self._call(inputs, run_manager=run_manager)
#     161         if new_arg_supported
#     162         else self._call(inputs)
#     163     )
#     165     final_outputs: Dict[str, Any] = self.prep_outputs(
#     166         inputs, outputs, return_only_outputs
#     167     )
#     168 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:126, in LLMChain._call(self, inputs, run_manager)
#     121 def _call(
#     122     self,
#     123     inputs: Dict[str, Any],
#     124     run_manager: Optional[CallbackManagerForChainRun] = None,
#     125 ) -> Dict[str, str]:
# --> 126     response = self.generate([inputs], run_manager=run_manager)
#     127     return self.create_outputs(response)[0]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain\chains\llm.py:138, in LLMChain.generate(self, input_list, run_manager)
#     136 callbacks = run_manager.get_child() if run_manager else None
#     137 if isinstance(self.llm, BaseLanguageModel):
# --> 138     return self.llm.generate_prompt(
#     139         prompts,
#     140         stop,
#     141         callbacks=callbacks,
#     142         **self.llm_kwargs,
#     143     )
#     144 else:
#     145     results = self.llm.bind(stop=stop, **self.llm_kwargs).batch(
#     146         cast(List, prompts), {"callbacks": callbacks}
#     147     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:786, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     778 def generate_prompt(
#     779     self,
#     780     prompts: list[PromptValue],
#    (...)
#     783     **kwargs: Any,
#     784 ) -> LLMResult:
#     785     prompt_messages = [p.to_messages() for p in prompts]
# --> 786     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:643, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     641         if run_managers:
#     642             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 643         raise e
#     644 flattened_outputs = [
#     645     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     646     for res in results
#     647 ]
#     648 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:633, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     630 for i, m in enumerate(messages):
#     631     try:
#     632         results.append(
# --> 633             self._generate_with_cache(
#     634                 m,
#     635                 stop=stop,
#     636                 run_manager=run_managers[i] if run_managers else None,
#     637                 **kwargs,
#     638             )
#     639         )
#     640     except BaseException as e:
#     641         if run_managers:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_core\language_models\chat_models.py:851, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     849 else:
#     850     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 851         result = self._generate(
#     852             messages, stop=stop, run_manager=run_manager, **kwargs
#     853         )
#     854     else:
#     855         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\langchain_groq\chat_models.py:474, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     469 message_dicts, params = self._create_message_dicts(messages, stop)
#     470 params = {
#     471     **params,
#     472     **kwargs,
#     473 }
# --> 474 response = self.client.create(messages=message_dicts, **params)
#     475 return self._create_chat_result(response)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\groq\resources\chat\completions.py:298, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, parallel_tool_calls, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     157 def create(
#     158     self,
#     159     *,
#    (...)
#     186     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     187 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     188     """
#     189     Creates a model response for the given chat conversation.
#     190
#    (...)
#     296       timeout: Override the client-level default timeout for this request, in seconds
#     297     """
# --> 298     return self._post(
#     299         "/openai/v1/chat/completions",
#     300         body=maybe_transform(
#     301             {
#     302                 "messages": messages,
#     303                 "model": model,
#     304                 "frequency_penalty": frequency_penalty,
#     305                 "function_call": function_call,
#     306                 "functions": functions,
#     307                 "logit_bias": logit_bias,
#     308                 "logprobs": logprobs,
#     309                 "max_tokens": max_tokens,
#     310                 "n": n,
#     311                 "parallel_tool_calls": parallel_tool_calls,
#     312                 "presence_penalty": presence_penalty,
#     313                 "response_format": response_format,
#     314                 "seed": seed,
#     315                 "stop": stop,
#     316                 "stream": stream,
#     317                 "temperature": temperature,
#     318                 "tool_choice": tool_choice,
#     319                 "tools": tools,
#     320                 "top_logprobs": top_logprobs,
#     321                 "top_p": top_p,
#     322                 "user": user,
#     323             },
#     324             completion_create_params.CompletionCreateParams,
#     325         ),
#     326         options=make_request_options(
#     327             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     328         ),
#     329         cast_to=ChatCompletion,
#     330         stream=stream or False,
#     331         stream_cls=Stream[ChatCompletionChunk],
#     332     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\groq\_base_client.py:1261, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1247 def post(
#    1248     self,
#    1249     path: str,
#    (...)
#    1256     stream_cls: type[_StreamT] | None = None,
#    1257 ) -> ResponseT | _StreamT:
#    1258     opts = FinalRequestOptions.construct(
#    1259         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1260     )
# -> 1261     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\groq\_base_client.py:953, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     950 else:
#     951     retries_taken = 0
# --> 953 return self._request(
#     954     cast_to=cast_to,
#     955     options=options,
#     956     stream=stream,
#     957     stream_cls=stream_cls,
#     958     retries_taken=retries_taken,
#     959 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\groq\_base_client.py:1056, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1053         err.response.read()
#    1055     log.debug("Re-raising status error")
# -> 1056     raise self._make_status_error_from_response(err.response) from None
#    1058 return self._process_response(
#    1059     cast_to=cast_to,
#    1060     options=options,
#    (...)
#    1064     retries_taken=retries_taken,
#    1065 )
#
# APIStatusError: Error code: 413 - {'error': {'message': 'Request too large for model `llama-3.3-70b-versatile` in organization `org_01jdb5bnksfzt803m2mpy97p1m` on tokens per minute (TPM): Limit 6000, Requested 58950, please reduce your message size and try again. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'tokens', 'code': 'rate_limit_exceeded'}}
